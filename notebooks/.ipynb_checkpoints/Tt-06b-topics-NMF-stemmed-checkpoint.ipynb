# %%
# =-=-=-=-=-=
# Read CSV into DataFrame and then create lists
# =-=-=-=-=-=

import pandas

# Create pandas dataframe & lists
colnames = ['author', 'title', 'date' , 'length', 'text']
df = pandas.read_csv('../data/talks_3.csv', names=colnames)
talks = df.text.tolist()

# =-=-=-=-=-=-=-=-=-=-=
# Create citations to identify individual texts
# =-=-=-=-=-=-=-=-=-=-= 
# authors = df.author.tolist()
# dates = df.date.tolist()
# years = [re.sub('[A-Za-z ]', '', item) for item in dates]
# authordate = [author+" "+year for author, year in zip(authors, years)]

# %%
# =-=-=-=-=-=
# Clean, Tokenize, Drop Stopwords, Stem
# =-=-=-=-=-=

from nltk.tokenize import WhitespaceTokenizer
from nltk.stem import *
from nltk.stem.porter import *

# Load tokenizer, stopwords, and stemmer
tokenizer = WhitespaceTokenizer()
stopwords = re.split('\s+', open('../data/tt_stop.txt', 'r').read().lower())
p_stemmer = PorterStemmer()

# Loop to tokenize, stop, and stem (if needed) texts.
texts = []
for i in talks:   
    # clean and tokenize document string
    raw = re.sub(r"[^\w\d'\s]+",'', i).lower()
    tokens = tokenizer.tokenize(raw)
    # remove stop words from tokens
    stopped_tokens = [i for i in tokens if not i in stopwords]
    # stem tokens
    stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]
    # add tokens to list
    texts.append(stemmed_tokens)

# =-=-=-=-=-=-=-=-=-=-=
# Re-Assemble Texts as Strings from Lists of Words
# =-=-=-=-=-=-=-=-=-=-= 

strungs = []
for text in texts:
    strung = ' '.join(text)
    strungs.append(strung)

# %%
# =-=-=-=-=-=
# Get NMF topics
# =-=-=-=-=-=

import sklearn.feature_extraction.text as sk_text
from sklearn.decomposition import NMF

# All our variables are here to make it easier to make adjustments
data_set = talks # or talks
n_samples = len(data_set)
n_features = 1500
n_topics = 35
n_top_words = 15
# tt_stopwords = open('../data/stopwords_tt.txt', 'r').read().splitlines()

# Get tf-idf features for NMF
vectorizer = sk_text.TfidfVectorizer(max_df = 0.90,
                                        min_df = 0.01,
                                        max_features = n_features)
tfidf = vectorizer.fit_transform(data_set)

# Fit the NMF model
nmf = NMF(n_components = n_topics,
          random_state = 1,
          alpha = 0.1,
          l1_ratio = 0.5).fit(tfidf)
print("Fitting the NMF model with {} topics for {} documents with {} features."
      .format(n_topics, n_samples, n_features))
# Out:
# Fitting the NMF model with 35 topics for 2068 documents with 1500 features.

# %%
# =-=-=-=-=-=
# Get NMF printing
# =-=-=-=-=-=

def print_top_words(model, feature_names, n_top_words):
    for topic_id, topic in enumerate(model.components_):
        print('\nTopic {}:'.format(int(topic_id)))
        print(''.join([feature_names[i] + ' ' + str(round(topic[i], 2))
              +', ' for i in topic.argsort()[:-n_top_words - 1:-1]]))

features = vectorizer.get_feature_names()
#print(features)

print("Topics in NMF model:")

# KK - I get an error here. My python does not recognize tfidf_vectorizer()
#tfidf_feature_names = nmf.get_feature_names()
# This works now. I added features above. Probably broken by me
# not seeing a name change. 
print_top_words(nmf, features, n_top_words) #n_top_words can be changed on the fly
# Out:
# Topics in NMF model:
#
# Topic 0:
# going 0.79, really 0.71, very 0.69, think 0.68, here 0.65, your 0.65, know 0.64, get 0.61, see 0.6, things 0.58, ve 0.57, some 0.54, then 0.53, don 0.52, right 0.49,
#
# Topic 1:
# she 3.09, her 2.17, said 0.22, mother 0.2, woman 0.2, girl 0.19, daughter 0.16, who 0.14, women 0.14, mom 0.1, their 0.1, husband 0.09, old 0.09, don 0.08, know 0.08,
#
# Topic 2:
# africa 2.0, african 0.78, hiv 0.32, south 0.23, countries 0.19, aid 0.16, leaders 0.16, aids 0.12, farmers 0.09, here 0.09, world 0.08, country 0.08, very 0.07, has 0.06, east 0.06,
#
# Topic 3:
# he 3.53, his 1.56, him 0.98, said 0.36, man 0.26, who 0.26, had 0.23, guy 0.2, himself 0.19, father 0.19, story 0.15, were 0.12, says 0.1, did 0.1, arm 0.1,
#
# Topic 4:
# brain 2.46, neurons 0.53, brains 0.33, your 0.25, activity 0.16, mental 0.15, arm 0.15, memory 0.14, body 0.13, human 0.13, consciousness 0.11, behavior 0.1, mind 0.1, visual 0.1, pain 0.09,
#
# Topic 5:
# universe 1.35, earth 0.55, planets 0.54, stars 0.53, space 0.45, light 0.39, planet 0.38, mars 0.31, sun 0.31, dark 0.26, solar 0.26, see 0.25, our 0.25, theory 0.24, star 0.22,
#
# Topic 6:
# ocean 1.27, fish 0.85, sea 0.74, ice 0.4, animals 0.34, planet 0.26, deep 0.23, earth 0.22, species 0.19, surface 0.18, water 0.18, climate 0.16, north 0.15, down 0.15, feet 0.14,
#
# Topic 7:
# cells 1.9, stem 0.69, cell 0.6, tissue 0.31, bone 0.25, body 0.25, disease 0.16, drug 0.16, lab 0.15, blood 0.13, skin 0.11, heart 0.11, grow 0.1, animal 0.09, drugs 0.09,
#
# Topic 8:
# children 2.02, child 0.88, parents 0.33, family 0.25, india 0.25, families 0.23, their 0.2, schools 0.18, school 0.14, boy 0.13, mother 0.11, will 0.1, education 0.08, very 0.08, countries 0.08,
#
# Topic 9:
# robot 1.75, robots 1.14, legs 0.09, move 0.09, video 0.08, its 0.07, see 0.07, lab 0.07, build 0.06, animal 0.05, machines 0.05, control 0.05, here 0.05, foot 0.04, intelligence 0.04,
#
# Topic 10:
# water 2.43, river 0.26, waste 0.19, bacteria 0.15, into 0.14, organisms 0.11, use 0.11, surface 0.1, clean 0.08, supply 0.08, environment 0.08, material 0.08, plastic 0.07, through 0.07, air 0.06,
#
# Topic 11:
# energy 1.35, oil 0.83, climate 0.39, nuclear 0.37, solar 0.34, carbon 0.33, gas 0.29, power 0.29, electricity 0.29, fuel 0.28, wind 0.21, per 0.17, our 0.17, use 0.16, co 0.16,
#
# Topic 12:
# language 1.38, english 1.07, word 0.54, words 0.52, speak 0.19, chinese 0.18, sound 0.14, speech 0.13, example 0.12, books 0.11, which 0.11, say 0.1, writing 0.1, learn 0.08, read 0.08,
#
# Topic 13:
# kids 1.26, school 0.99, students 0.89, teachers 0.68, education 0.65, teacher 0.36, learning 0.34, schools 0.31, teaching 0.27, teach 0.26, class 0.25, their 0.23, student 0.23, learn 0.21, kid 0.2,
#
# Topic 14:
# city 1.78, cities 1.23, urban 0.32, new 0.26, map 0.25, cars 0.25, york 0.25, street 0.21, park 0.19, streets 0.18, public 0.17, car 0.14, san 0.13, citizens 0.12, places 0.12,
#
# Topic 15:
# plants 0.87, forest 0.81, species 0.79, animals 0.6, plant 0.6, trees 0.58, tree 0.37, nature 0.23, carbon 0.21, animal 0.19, birds 0.16, planet 0.16, land 0.15, earth 0.15, grow 0.14,
#
# Topic 16:
# girls 1.75, girl 0.54, boys 0.32, school 0.21, their 0.11, father 0.09, afghanistan 0.08, who 0.08, dance 0.07, wish 0.07, boy 0.06, every 0.04, community 0.04, research 0.04, her 0.03,
#
# Topic 17:
# women 2.49, men 1.03, woman 0.38, sex 0.27, female 0.26, gender 0.25, male 0.18, who 0.16, violence 0.13, boys 0.09, girls 0.09, percent 0.08, man 0.08, talk 0.07, country 0.07,
#
# Topic 18:
# data 2.62, information 0.48, map 0.17, web 0.13, our 0.11, see 0.09, points 0.08, numbers 0.08, look 0.07, patterns 0.07, light 0.06, text 0.06, using 0.05, google 0.05, car 0.04,
#
# Topic 19:
# building 1.11, buildings 0.68, architecture 0.66, space 0.51, project 0.34, built 0.25, materials 0.24, build 0.23, air 0.2, museum 0.2, material 0.18, structure 0.17, light 0.17, site 0.17, house 0.17,
#
# Topic 20:
# music 2.11, sound 0.65, play 0.4, song 0.32, hear 0.26, playing 0.19, piece 0.19, listening 0.18, listen 0.17, played 0.16, hearing 0.15, sounds 0.15, me 0.12, video 0.11, voice 0.1,
#
# Topic 21:
# dna 1.5, genome 0.56, bacteria 0.52, genes 0.45, gene 0.41, genetic 0.35, cell 0.27, virus 0.26, species 0.22, code 0.22, biology 0.16, molecules 0.16, organisms 0.14, evolution 0.12, technology 0.09,
#
# Topic 22:
# me 1.48, had 0.89, said 0.57, were 0.5, life 0.41, would 0.37, myself 0.36, love 0.34, know 0.34, went 0.33, day 0.32, didn 0.31, never 0.3, no 0.3, who 0.3,
#
# Topic 23:
# design 2.2, designers 0.67, designed 0.24, products 0.13, product 0.13, technology 0.1, work 0.1, art 0.1, new 0.1, beautiful 0.09, object 0.08, really 0.08, process 0.08, kind 0.07, materials 0.07,
#
# Topic 24:
# internet 0.89, computer 0.8, information 0.65, technology 0.6, machine 0.52, digital 0.51, web 0.5, computers 0.42, phone 0.37, online 0.37, video 0.34, media 0.33, mobile 0.29, software 0.28, machines 0.25,
#
# Topic 25:
# babies 1.4, baby 0.68, learning 0.18, birth 0.1, evidence 0.08, born 0.07, mother 0.06, sounds 0.04, voice 0.04, learn 0.04, woman 0.04, month 0.04, critical 0.04, world 0.03, months 0.03,
#
# Topic 26:
# countries 0.63, percent 0.52, china 0.52, dollars 0.47, india 0.44, money 0.43, growth 0.42, world 0.42, economic 0.39, economy 0.39, country 0.38, billion 0.36, market 0.31, global 0.31, income 0.3,
#
# Topic 27:
# actually 2.74, very 0.27, which 0.25, really 0.21, basically 0.19, sort 0.12, material 0.09, value 0.08, also 0.08, project 0.06, interesting 0.06, technology 0.06, bone 0.06, materials 0.05, able 0.05,
#
# Topic 28:
# game 1.27, games 1.22, play 0.77, video 0.57, playing 0.32, real 0.08, played 0.08, win 0.08, physical 0.07, world 0.06, fun 0.06, online 0.05, social 0.05, action 0.04, right 0.04,
#
# Topic 29:
# cancer 2.25, body 0.18, disease 0.18, drug 0.17, blood 0.15, tissue 0.1, surgery 0.07, her 0.07, molecules 0.07, gene 0.07, treatment 0.06, cell 0.06, lab 0.06, percent 0.05, our 0.05,
#
# Topic 30:
# compassion 1.64, god 0.37, religious 0.16, suffering 0.12, love 0.09, rule 0.08, happy 0.08, religion 0.07, world 0.07, beings 0.06, says 0.06, zero 0.06, human 0.05, being 0.05, yourself 0.05,
#
# Topic 31:
# food 1.92, eat 0.53, farmers 0.37, feed 0.28, eating 0.25, waste 0.23, plant 0.22, fish 0.2, our 0.17, plants 0.14, kids 0.12, healthy 0.11, local 0.1, growing 0.1, production 0.1,
#
# Topic 32:
# patients 0.92, health 0.8, disease 0.58, patient 0.57, hiv 0.5, care 0.47, medical 0.42, drugs 0.41, doctors 0.37, treatment 0.35, drug 0.33, medicine 0.3, hospital 0.28, doctor 0.28, heart 0.27,
#
# Topic 33:
# fly 1.59, flying 0.47, neurons 0.16, baby 0.15, its 0.13, control 0.1, space 0.09, air 0.09, camera 0.08, model 0.08, birds 0.07, dream 0.06, down 0.06, field 0.05, machines 0.05,
#
# Topic 34:
# our 1.18, their 0.75, us 0.56, were 0.47, who 0.46, world 0.4, war 0.3, social 0.29, human 0.28, been 0.28, has 0.28, many 0.27, will 0.26, than 0.26, new 0.25,

# %%
dtm = tfidf.toarray()
doctopic = nmf.fit_transform(dtm) # This is an array

dtm.shape

# %%
for topicidx in enumerate(nmf.components_):
    print(topicidx)

# %%
# =-=-=-=-=-=
# Saving output to CSV
# =-=-=-=-=-=

import numpy as np

# Since DOCTOPIC is an array, you can just do:
#      np.savetxt("foo.csv", doctopic, delimiter=",", fmt = "%s")
# http://stackoverflow.com/questions/6081008/dump-a-numpy-array-into-a-csv-file
#
# The above won't give you the names of the files. Instead try this:

topsnum = np.array([list(range(n_topics))])
# topsnum = np.indices((1,n_topics))[1] <-- this is more than we need,
#                                           but it's cool to know more tricks
#
# Two ways to get an array that is of the form [[0,1,2,3,...]].
# It will have the desired dimensions of (1,35) which is what we want

fileheader = np.concatenate((np.array([["citations"]]), topsnum),axis = 1)
authordate = np.array([df.author])

docTopics = np.concatenate((authordate.T, doctopic), axis = 1)
docTopics = np.concatenate((fileheader, docTopics), axis = 0)

np.savetxt("../data/dt_KK_test.csv", doctopic, delimiter=",", fmt = "%s")
#np.savetxt("../data/nmf_topics.csv", docTopics, delimiter=",", fmt = "%s")
