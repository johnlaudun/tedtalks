# %% [markdown]
# # Subjective Verbs

# %% [markdown]
# This notebook seeks to merge ideas in the 2 SV pair notebooks.
#
# ## How do we relate back to `I`?

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>A note about the naming of variables below:</p>
#     <ul>
#         <li><code>m</code> and <code>w</code> represent the subcorpus, men or women speakers</li>
#         <li><code>pp</code> stands for personal pronouns, usually "he," "she," and "I" here.
#         <li><code>svo</code> signifies that the complete SVO-triplet is used</li>
#         <li><code>sv</code> signifies that just the subject-verb pairs are being used</li>
#     </ul>
# </div>

# %% [markdown]
# What we want to explore is both the usual ways that speakers (men or women) pair the pronouns *he*, *she*, *i* with verbs and also, perhaps, the significant pairings. The usual way can be approached via **counts**, which we have visualized in a separate notebook with Sankey plots.
#
# Relative frequencies would let us compare across the two subcorpora ... or would this be approached better by some form of TF-IDF? (And would we need to determine some sort of lower threshold of the number of sentences in which a verb must occur? We're not interested in verb only used in a single sentence but verbs used often in a pairing in one subcorpus and not in the other.)

# %%
# IMPORTS
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# LOAD DATAFRAMES
# the `lem` suffix indicates the verbs have been lemmatized
svos_m = pd.read_csv("../output/svos_m_lem.csv", index_col=0)
svos_w = pd.read_csv("../output/svos_w_lem.csv", index_col=0)

# Save the SVO count for each corpus for calculating relative frequencies
m_svo_count = svos_m.shape[0]
w_svo_count = svos_w.shape[0]

# Output something to check our efforts
print(m_svo_count, w_svo_count)
# Out:
# 80460 26610

# %%
svos_m
# Out:
#         subject     verb                                             object
# 0             i     blow                                       [conference]
# 1             i     want  [to, thank, all, of, you, for, the, many, nice...
# 2             i     need                                             [that]
# 3      laughter      put                                       [yourselves]
# 4             i      fly                                              [two]
# ...         ...      ...                                                ...
# 80455       you  imagine                                              [him]
# 80456       you      see                                   [credit, rating]
# 80457        we       do                                             [what]
# 80458        it   expose                                         [humanity]
# 80459        it   reveal                                           [demons]
#
# [80460 rows x 3 columns]

# %% [markdown]
# ## SV Pairs with "She", "He", and "I"

# %%
# Create a list of the pronouns we want to see
pronouns = ["he", "she", "i"]

# Function to retrive the count the number of times subjects,
# here a list of pronouns, are paired with verbs
def svPairs (df, pplist):    
    temp = df[df["subject"].isin(
        pplist)].value_counts(
        subset=['subject', 'verb']).reset_index()
    # Re-label the new column from "0" to something human-readable
    temp.rename(columns={0:'v_freq'}, inplace=True)
    # Add a column with relative frequency
    temp['v_rfreq'] = temp['v_freq'] / df.shape[0]
    return temp

# %%
m_pp_v = svPairs(svos_m, pronouns)
w_pp_v = svPairs(svos_w, pronouns)

print(m_pp_v.shape)
print(w_pp_v.shape)

# m_pp_v.to_csv("../output/m_pp_v.csv")
# w_pp_v.to_csv("../output/w_pp_v.csv")
# Out:
# (1723, 4)
# (1069, 4)

# %%
m_pp_v.head()
# Out:
#   subject  verb  v_freq   v_rfreq
# 0       i  have    1318  0.016381
# 1       i  want    1210  0.015039
# 2       i    go    1076  0.013373
# 3       i    do     650  0.008079
# 4       i   get     586  0.007283

# %% [markdown]
# ## Subjects as Verb Features
#
# In the cells below, we …
#
# 1. **create 6 distinct dataframes**, one each for men and women speakers and the three pronouns.
# 2. **transpose each "subjective" dataframe** into a single row with the verbs associated with as columns and their relative frequencies as values.
# 3. **stack those rows** to get a unified dataframe with all 6 subject positions and verbs associated with them.
# 4. **transpose unified dataframe** to have the features as rows and the speaker-pronoun documents as columns (so we can do some math on the features). I.e., `verbs` dataframe below.

# %%
# function to filter SVOs for 
def filterdrop (df, pronoun, threshold):
    dftemp = df.loc[(df['subject'] == pronoun)]
    dftemp = dftemp.drop(columns=['subject', 'v_rfreq'])
    dftemp = dftemp[dftemp.v_freq > threshold]
    return dftemp

# %%
# Establish the minimum number of instances a verb occurs
# for us to consider it
verb_min = 2

# Create our pronoun-verb dataframes for he, she, i
m_he = filterdrop(m_pp_v, "he", verb_min)
w_he = filterdrop(w_pp_v, "he", verb_min)

m_she = filterdrop(m_pp_v, "she", verb_min)
w_she = filterdrop(w_pp_v, "she", verb_min)

m_i = filterdrop(m_pp_v, "i", verb_min)
w_i = filterdrop(w_pp_v, "i", verb_min)

# Print counts & preview a dataframe
print(f"m_he:  {m_he.shape[0]}, w_he:  {w_he.shape[0]}")
print(f"m_she: {m_she.shape[0]}, w_she: {w_she.shape[0]}")
print(f"m_i:   {m_i.shape[0]}, w_i:   {w_i.shape[0]}")
print("\n w_i looks like:")
print(w_i.head())
# Out:
# m_he:  141, w_he:  56
# m_she: 58, w_she: 55
# m_i:   380, w_i:   213
#
#  w_i looks like:
#    verb  v_freq
# 0  have     586
# 1  want     424
# 2    go     330
# 3    do     226
# 4   get     203

# %%
# This function takes the two columns of verb and count,
# transposes them, into a dataframe of a single row,
# with the verb as the column name
def makestackable (df, indexname):
    df_T = df.transpose()
    df_T.columns = df_T.iloc[0]
    df_T.drop(index=df_T.index[0], axis=0, inplace=True)
    df_T.index = [indexname]
    return df_T

# We use the function to create 6 dataframes
m_it = makestackable(m_i, "m_i")
w_it = makestackable(w_i, "w_i")
m_het = makestackable(m_he, "m_he")
w_het = makestackable(w_he, "w_he")
m_shet = makestackable(m_she, "m_she")
w_shet = makestackable(w_she, "w_she")

# ... that we then "stack" together 
# with the verbs as columns and the counts as values
concatenated = pd.concat([w_it, m_it, w_het, m_het, w_shet, m_shet])
concatenated.fillna(0, inplace=True)

# List of verbs
verb_list = list(concatenated.columns)

# View the results
concatenated.head(6)
# Out:
# verb   have  want    go   do  get  tell  like  know  start  love  ...  fund  \
# w_i     586   424   330  226  203   169   160   154    145   137  ...     0
# m_i    1318  1210  1076  650  586   326   462   274    377   271  ...     0
# w_he     80    20    32   29   19    16     7     4     12     4  ...     0
# m_he    232    71    78  111   90    58    14    27     42     5  ...     3
# w_she    63    11    22   33   20    18     6     6      9    10  ...     0
# m_she    94    32    34   41   24    20     5    10     17     4  ...     0
#
# verb   postulate  appeal  escape  suffer  sue  spin  brush  feed  lower
# w_i            0       0       0       0    0     0      0     0      0
# m_i            0       0       0       0    0     0      0     0      0
# w_he           0       0       0       0    0     0      0     0      0
# m_he           3       3       3       3    3     3      0     0      0
# w_she          0       0       0       0    0     0      3     3      0
# m_she          0       0       0       0    0     0      0     0      3
#
# [6 rows x 415 columns]

# %%
# Having done the work above, we now rotate the dataframe again
# in order to have the speaker-pronouns as columns and the verbs as rows
verbs = concatenated.transpose()
print(verbs.shape)
print(verbs.head())
# Out:
# (415, 6)
#       w_i   m_i  w_he  m_he  w_she  m_she
# verb
# have  586  1318    80   232     63     94
# want  424  1210    20    71     11     32
# go    330  1076    32    78     22     34
# do    226   650    29   111     33     41
# get   203   586    19    90     20     24

# %% [markdown]
# > ***He/She Variant***: The cell below creates a dataframe with only the 2 x 2 speaker gender and subject gender and names it the same as the 2 x 3 dataframe, which includes the *I*, above. Please make sure you know which one you want to see.

# %%
heshe = pd.concat([m_het, w_het, m_shet, w_shet])
heshe.fillna(0, inplace=True)

# List of verbs
verb_list = list(heshe.columns)

# The transpose
verbs = heshe.transpose()
print(verbs.shape)
print(verbs.head())
# Out:
# (160, 4)
#       m_he  w_he  m_she  w_she
# verb
# have   232    80     94     63
# say    132    39     47     31
# do     111    29     41     33
# get     90    19     24     20
# go      78    32     34     22

# %% [markdown]
# ### The TF-IDF Part
#
# We are going to treat each of the speaker-pronoun columns as a document, so that we can explore which verbs are evenly distributed across the pairings and which differentiate the actions available to a subject.

# %% [markdown]
# #### With Relative Frequency of Terms within Pseudo-Documents

# %%
# We need totals both by term (rows) and by document (columns)
# A peculiarity of pandas means we need to get rows first, then columns

# Totals per verb:
verbs["total"] = verbs.sum(axis = 1)

# Totals per document
doc_totals = verbs.sum(axis = 0)

# To hold our totals
new_verbs = verbs.copy()

# View the total number of s-v pairs per pronoun
doc_totals

# Get TF by "document"
verbs_rel = verbs/doc_totals

# A quick visual check COMMENTED OUT
# verbs_rel.head(10).style.background_gradient(axis=None, cmap='icefire')

# Reclaim our totals:
verbs_rel["total"] = new_verbs["total"]
verbs_rel.head()

# establish that we only want to work on the counts
# for each pronoun and not the total
cols = verbs_rel.columns
cols = list(cols)[:-1]


# the TFIDF part
for col in cols:
    verbs_rel[col] = (1/new_verbs["total"])*verbs_rel[col]

tfidf = verbs_rel.drop(columns=['total'])

# %%
doc_totals
# Out:
# m_he     2098
# w_he      528
# m_she     625
# w_she     447
# total    3698
# dtype: int64

# %%
tfidf.head(10)
# Out:
#           m_he      w_he     m_she     w_she
# verb
# have  0.000236  0.000323  0.000321  0.000301
# say   0.000253  0.000297  0.000302  0.000279
# do    0.000247  0.000257  0.000307  0.000345
# get   0.000280  0.000235  0.000251  0.000292
# go    0.000224  0.000365  0.000328  0.000296
# take  0.000269  0.000316  0.000267  0.000227
# want  0.000253  0.000283  0.000382  0.000184
# make  0.000290  0.000241  0.000233  0.000264
# tell  0.000247  0.000271  0.000286  0.000360
# put   0.000343  0.000253  0.000107  0.000179

# %%
tfidf.style.background_gradient(axis=None, cmap='Purples')
# Out:
# <style type="text/css">
# #T_8e9bc_row0_col0, #T_8e9bc_row3_col1, #T_8e9bc_row7_col2, #T_8e9bc_row12_col0, #T_8e9bc_row20_col0 {
#   background-color: #f1f0f6;
#   color: #000000;
# }
# #T_8e9bc_row0_col1, #T_8e9bc_row0_col2, #T_8e9bc_row5_col1, #T_8e9bc_row15_col3, #T_8e9bc_row17_col1, #T_8e9bc_row49_col2, #T_8e9bc_row50_col0, #T_8e9bc_row69_col0, #T_8e9bc_row72_col0 {
#   background-color: #ecebf4;
#   color: #000000;
# }
# #T_8e9bc_row0_col3, #T_8e9bc_row1_col2, #T_8e9bc_row15_col0, #T_8e9bc_row31_col2, #T_8e9bc_row43_col2, #T_8e9bc_row52_col2, #T_8e9bc_row57_col0, #T_8e9bc_row63_col0, #T_8e9bc_row75_col0 {
#   background-color: #eeecf4;
#   color: #000000;
# }
# #T_8e9bc_row1_col0, #T_8e9bc_row2_col0, #T_8e9bc_row3_col2, #T_8e9bc_row6_col0, #T_8e9bc_row7_col1, #T_8e9bc_row8_col0, #T_8e9bc_row9_col1, #T_8e9bc_row11_col0, #T_8e9bc_row11_col3, #T_8e9bc_row14_col2, #T_8e9bc_row18_col3, #T_8e9bc_row30_col2, #T_8e9bc_row38_col0, #T_8e9bc_row41_col0, #T_8e9bc_row41_col2, #T_8e9bc_row55_col0, #T_8e9bc_row81_col0, #T_8e9bc_row124_col0, #T_8e9bc_row130_col0 {
#   background-color: #f1eff6;
#   color: #000000;
# }
# #T_8e9bc_row1_col1, #T_8e9bc_row3_col3, #T_8e9bc_row4_col3, #T_8e9bc_row7_col0, #T_8e9bc_row14_col0, #T_8e9bc_row24_col0, #T_8e9bc_row24_col3, #T_8e9bc_row26_col1, #T_8e9bc_row34_col0 {
#   background-color: #eeecf5;
#   color: #000000;
# }
# #T_8e9bc_row1_col3, #T_8e9bc_row3_col0, #T_8e9bc_row6_col1, #T_8e9bc_row8_col2, #T_8e9bc_row11_col1, #T_8e9bc_row16_col0, #T_8e9bc_row16_col3, #T_8e9bc_row27_col0, #T_8e9bc_row31_col0, #T_8e9bc_row35_col0, #T_8e9bc_row37_col2, #T_8e9bc_row41_col1, #T_8e9bc_row51_col0, #T_8e9bc_row60_col0, #T_8e9bc_row85_col2, #T_8e9bc_row90_col0, #T_8e9bc_row93_col0, #T_8e9bc_row99_col0, #T_8e9bc_row111_col0 {
#   background-color: #efedf5;
#   color: #000000;
# }
# #T_8e9bc_row2_col1, #T_8e9bc_row17_col0, #T_8e9bc_row20_col1, #T_8e9bc_row22_col3, #T_8e9bc_row49_col0, #T_8e9bc_row64_col0, #T_8e9bc_row66_col0 {
#   background-color: #f0eef6;
#   color: #000000;
# }
# #T_8e9bc_row2_col2, #T_8e9bc_row10_col0, #T_8e9bc_row12_col1, #T_8e9bc_row18_col0, #T_8e9bc_row18_col1, #T_8e9bc_row21_col2, #T_8e9bc_row26_col0, #T_8e9bc_row26_col2, #T_8e9bc_row29_col0, #T_8e9bc_row37_col0 {
#   background-color: #edebf4;
#   color: #000000;
# }
# #T_8e9bc_row2_col3, #T_8e9bc_row9_col0, #T_8e9bc_row53_col0, #T_8e9bc_row55_col2 {
#   background-color: #eae9f3;
#   color: #000000;
# }
# #T_8e9bc_row4_col0, #T_8e9bc_row5_col3, #T_8e9bc_row22_col0, #T_8e9bc_row23_col0, #T_8e9bc_row25_col0, #T_8e9bc_row25_col2, #T_8e9bc_row48_col0, #T_8e9bc_row61_col0, #T_8e9bc_row68_col0 {
#   background-color: #f2f0f7;
#   color: #000000;
# }
# #T_8e9bc_row4_col1, #T_8e9bc_row8_col3, #T_8e9bc_row25_col1, #T_8e9bc_row39_col0 {
#   background-color: #e9e8f2;
#   color: #000000;
# }
# #T_8e9bc_row4_col2, #T_8e9bc_row14_col3, #T_8e9bc_row20_col2, #T_8e9bc_row85_col1 {
#   background-color: #eceaf3;
#   color: #000000;
# }
# #T_8e9bc_row5_col0, #T_8e9bc_row5_col2, #T_8e9bc_row7_col3, #T_8e9bc_row8_col1, #T_8e9bc_row19_col0, #T_8e9bc_row27_col1, #T_8e9bc_row36_col1, #T_8e9bc_row38_col1, #T_8e9bc_row43_col0, #T_8e9bc_row62_col2 {
#   background-color: #f0eef5;
#   color: #000000;
# }
# #T_8e9bc_row6_col2, #T_8e9bc_row13_col2, #T_8e9bc_row28_col0 {
#   background-color: #e8e6f2;
#   color: #000000;
# }
# #T_8e9bc_row6_col3, #T_8e9bc_row10_col3, #T_8e9bc_row36_col0, #T_8e9bc_row62_col0, #T_8e9bc_row101_col0, #T_8e9bc_row110_col0 {
#   background-color: #f3f2f8;
#   color: #000000;
# }
# #T_8e9bc_row9_col2 {
#   background-color: #f7f6fa;
#   color: #000000;
# }
# #T_8e9bc_row9_col3, #T_8e9bc_row14_col1, #T_8e9bc_row52_col0, #T_8e9bc_row83_col0 {
#   background-color: #f4f2f8;
#   color: #000000;
# }
# #T_8e9bc_row10_col1, #T_8e9bc_row11_col2, #T_8e9bc_row16_col2, #T_8e9bc_row22_col2 {
#   background-color: #ebe9f3;
#   color: #000000;
# }
# #T_8e9bc_row10_col2, #T_8e9bc_row19_col1, #T_8e9bc_row84_col0 {
#   background-color: #f6f4f9;
#   color: #000000;
# }
# #T_8e9bc_row12_col2, #T_8e9bc_row30_col3, #T_8e9bc_row34_col1, #T_8e9bc_row52_col3, #T_8e9bc_row62_col1 {
#   background-color: #e4e3f0;
#   color: #000000;
# }
# #T_8e9bc_row12_col3, #T_8e9bc_row13_col0, #T_8e9bc_row13_col3, #T_8e9bc_row15_col1, #T_8e9bc_row15_col2, #T_8e9bc_row29_col2, #T_8e9bc_row30_col0 {
#   background-color: #f3f1f7;
#   color: #000000;
# }
# #T_8e9bc_row13_col1, #T_8e9bc_row32_col0, #T_8e9bc_row33_col0, #T_8e9bc_row36_col3, #T_8e9bc_row40_col0, #T_8e9bc_row42_col0, #T_8e9bc_row43_col1, #T_8e9bc_row44_col0, #T_8e9bc_row46_col0, #T_8e9bc_row47_col0, #T_8e9bc_row54_col0, #T_8e9bc_row56_col0, #T_8e9bc_row58_col0, #T_8e9bc_row59_col0, #T_8e9bc_row65_col0, #T_8e9bc_row67_col0, #T_8e9bc_row70_col0, #T_8e9bc_row71_col0, #T_8e9bc_row73_col0, #T_8e9bc_row74_col0, #T_8e9bc_row76_col0, #T_8e9bc_row77_col0, #T_8e9bc_row78_col0, #T_8e9bc_row79_col0, #T_8e9bc_row80_col0, #T_8e9bc_row82_col0, #T_8e9bc_row86_col0, #T_8e9bc_row87_col0, #T_8e9bc_row88_col0, #T_8e9bc_row89_col0, #T_8e9bc_row91_col0, #T_8e9bc_row92_col0, #T_8e9bc_row94_col0, #T_8e9bc_row95_col0, #T_8e9bc_row96_col0, #T_8e9bc_row97_col0, #T_8e9bc_row98_col0, #T_8e9bc_row100_col0, #T_8e9bc_row102_col0, #T_8e9bc_row103_col0, #T_8e9bc_row104_col0, #T_8e9bc_row105_col0, #T_8e9bc_row106_col0, #T_8e9bc_row107_col0, #T_8e9bc_row108_col0, #T_8e9bc_row109_col0, #T_8e9bc_row112_col0, #T_8e9bc_row113_col0, #T_8e9bc_row114_col0, #T_8e9bc_row115_col0, #T_8e9bc_row116_col0, #T_8e9bc_row117_col0, #T_8e9bc_row118_col0, #T_8e9bc_row119_col0, #T_8e9bc_row121_col0, #T_8e9bc_row122_col0, #T_8e9bc_row123_col0, #T_8e9bc_row125_col0, #T_8e9bc_row126_col0, #T_8e9bc_row127_col0, #T_8e9bc_row128_col0, #T_8e9bc_row129_col0, #T_8e9bc_row131_col0, #T_8e9bc_row132_col0, #T_8e9bc_row133_col0, #T_8e9bc_row134_col0, #T_8e9bc_row135_col0, #T_8e9bc_row136_col0, #T_8e9bc_row137_col0, #T_8e9bc_row138_col0, #T_8e9bc_row139_col0, #T_8e9bc_row140_col0 {
#   background-color: #e0e0ee;
#   color: #000000;
# }
# #T_8e9bc_row16_col1, #T_8e9bc_row120_col0 {
#   background-color: #f5f3f8;
#   color: #000000;
# }
# #T_8e9bc_row17_col2, #T_8e9bc_row34_col3, #T_8e9bc_row39_col2, #T_8e9bc_row68_col2 {
#   background-color: #e8e7f2;
#   color: #000000;
# }
# #T_8e9bc_row17_col3 {
#   background-color: #f5f4f9;
#   color: #000000;
# }
# #T_8e9bc_row18_col2 {
#   background-color: #f6f5f9;
#   color: #000000;
# }
# #T_8e9bc_row19_col2, #T_8e9bc_row63_col2, #T_8e9bc_row68_col1, #T_8e9bc_row83_col1 {
#   background-color: #d8d8ea;
#   color: #000000;
# }
# #T_8e9bc_row19_col3, #T_8e9bc_row21_col1, #T_8e9bc_row21_col3, #T_8e9bc_row24_col1, #T_8e9bc_row26_col3, #T_8e9bc_row28_col1, #T_8e9bc_row28_col2, #T_8e9bc_row29_col3, #T_8e9bc_row31_col1, #T_8e9bc_row32_col1, #T_8e9bc_row32_col2, #T_8e9bc_row32_col3, #T_8e9bc_row33_col1, #T_8e9bc_row33_col2, #T_8e9bc_row33_col3, #T_8e9bc_row34_col2, #T_8e9bc_row35_col2, #T_8e9bc_row35_col3, #T_8e9bc_row37_col1, #T_8e9bc_row38_col3, #T_8e9bc_row39_col1, #T_8e9bc_row39_col3, #T_8e9bc_row40_col1, #T_8e9bc_row40_col2, #T_8e9bc_row40_col3, #T_8e9bc_row42_col1, #T_8e9bc_row42_col2, #T_8e9bc_row42_col3, #T_8e9bc_row43_col3, #T_8e9bc_row44_col1, #T_8e9bc_row44_col2, #T_8e9bc_row44_col3, #T_8e9bc_row45_col1, #T_8e9bc_row45_col3, #T_8e9bc_row46_col1, #T_8e9bc_row46_col2, #T_8e9bc_row46_col3, #T_8e9bc_row47_col1, #T_8e9bc_row47_col2, #T_8e9bc_row47_col3, #T_8e9bc_row48_col2, #T_8e9bc_row49_col1, #T_8e9bc_row50_col1, #T_8e9bc_row50_col2, #T_8e9bc_row51_col2, #T_8e9bc_row51_col3, #T_8e9bc_row53_col1, #T_8e9bc_row53_col2, #T_8e9bc_row54_col1, #T_8e9bc_row54_col2, #T_8e9bc_row54_col3, #T_8e9bc_row55_col3, #T_8e9bc_row56_col1, #T_8e9bc_row56_col2, #T_8e9bc_row56_col3, #T_8e9bc_row57_col2, #T_8e9bc_row57_col3, #T_8e9bc_row58_col1, #T_8e9bc_row58_col2, #T_8e9bc_row58_col3, #T_8e9bc_row59_col1, #T_8e9bc_row59_col2, #T_8e9bc_row59_col3, #T_8e9bc_row60_col1, #T_8e9bc_row60_col3, #T_8e9bc_row61_col2, #T_8e9bc_row63_col1, #T_8e9bc_row63_col3, #T_8e9bc_row64_col2, #T_8e9bc_row64_col3, #T_8e9bc_row65_col1, #T_8e9bc_row65_col2, #T_8e9bc_row65_col3, #T_8e9bc_row66_col1, #T_8e9bc_row66_col3, #T_8e9bc_row67_col1, #T_8e9bc_row67_col2, #T_8e9bc_row67_col3, #T_8e9bc_row68_col3, #T_8e9bc_row69_col1, #T_8e9bc_r

# %%
perception = tfidf.copy()

# Create a "group" summary for "lean" for each verb. That is, do the tfidf-y values for each verb lean
# men or women

perception["group_lean"] = (perception["m_he"] + perception["w_he"]) - (perception["m_she"] + perception["w_she"])

# %%
# Create a "male" summary for perceived "lean" for each verb. That is, do the tfidf-y values 
# for each verb spoken by men lean men or women
perception["male_lean"] = perception["m_he"] - perception["m_she"]

# %%
# Create a "female" summary for perceived "lean" for each verb. That is, do the tfidf-y values 
# for each verb spoken by women lean men or women

perception["female_lean"] = perception["w_he"] - perception["w_she"]

# %%
perception
# Out:
#               m_he      w_he     m_she     w_she  group_lean  male_lean  \
# verb
# have      0.000236  0.000323  0.000321  0.000301   -0.000062  -0.000085
# say       0.000253  0.000297  0.000302  0.000279   -0.000031  -0.000049
# do        0.000247  0.000257  0.000307  0.000345   -0.000148  -0.000059
# get       0.000280  0.000235  0.000251  0.000292   -0.000028   0.000029
# go        0.000224  0.000365  0.000328  0.000296   -0.000035  -0.000104
# ...            ...       ...       ...       ...         ...        ...
# miss      0.000000  0.000000  0.000000  0.002237   -0.002237   0.000000
# remember  0.000000  0.000000  0.000000  0.002237   -0.002237   0.000000
# gon       0.000000  0.000000  0.000000  0.002237   -0.002237   0.000000
# feed      0.000000  0.000000  0.000000  0.002237   -0.002237   0.000000
# sleep     0.000000  0.000000  0.000000  0.002237   -0.002237   0.000000
#
#           female_lean
# verb
# have         0.000023
# say          0.000018
# do          -0.000088
# get         -0.000057
# go           0.000069
# ...               ...
# miss        -0.002237
# remember    -0.002237
# gon         -0.002237
# feed        -0.002237
# sleep       -0.002237
#
# [160 rows x 7 columns]

# %%
plt.plot(perception["female_lean"],perception["group_lean"], "*")

# %%
perception["group_lean"].corr(perception["male_lean"])
# Out:
# 0.5466172936889899

# %%
perception["group_lean"].corr(perception["female_lean"])
# Out:
# 0.8478340140540096

# %%
perception["male_lean"].corr(perception["female_lean"])
# Out:
# 0.01940882884708376
