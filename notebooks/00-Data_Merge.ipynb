# %% [markdown]
# # Merging `only` and `plus` dataframes
#
# Working with only the data from the release, we have two files:
#
#     TEDonly_speakers_final.csv
#     TEDplus_speakers_final.csv
#
# The first thing we will do is to load both as `pandas` dataframes, but I think we also want to consider creating a merged file -- something like `TEDall.csv`. We are only going to need to do this once. From then on, we will work with either that data or an extended version of that data.

# %%
import pandas as pd

df_only = pd.read_csv('../data/Release_v0/TEDonly_speakers_final.csv')
df_plus = pd.read_csv('../data/Release_v0/TEDplus_speakers_final.csv')

print("df_only = ", df_only.shape, "\n" + "df_plus = ", df_plus.shape)
# Out:
# df_only =  (992, 27)
# df_plus =  (755, 27)

# %% [markdown]
# That's a lot of columns. Let's check the column names so that, first, we know we can merge the two dataframes without a problem, and, second, so that we can make sure to use the right column name later to get the texts of the talks.

# %%
# The pythonic way to open a file and get data:
with open('../data/Release_v0/TEDonly_speakers_final.csv') as f:
    cols_only = f.readline().strip().split(",")
with open('../data/Release_v0/TEDplus_speakers_final.csv') as f:
    cols_plus = f.readline().strip().split(",")

if cols_only == cols_plus:
    print("We are clear to merge.")
else:
    print("Houston, we have a problem.")
# Out:
# We are clear to merge.

# %% [markdown]
# Pandas allows us to **concatenate** dataframes by row, when our observations have the same metadata; **merge** by columns, when we have additional information for our observations; and **join**, which has all the usual functionalities, and complexities, of SQL joins. Our dataframes have the same columns, so we are going to concatenate the two and then write the combined data to a new `csv`.
#
# To do that, we are going to add a key column to each dataframe so that if we ever need to know which of the two dataframes a particular talk came from, we will be able to get that information readily. All we are going to do is add a column called `set` which will have one of two values, `only` or `plus`. The basic method of doing this is:
#
# ```python
# df['Name']='abc'
# ```
#
# But we are going to be a little more elaborate, because we would like to have this information on the left-hand side of the dataframe.

# %%
df_only.insert(0, 'Set', 'only')

# %%
df_only.head(3)
# Out:
#     Set  Unnamed: 0  Talk_ID  \
# 0  only           0        1
# 1  only           1        7
# 2  only           2       53
#
#                                           public_url  \
# 0  https://www.ted.com/talks/al_gore_on_averting_...
# 1  https://www.ted.com/talks/david_pogue_says_sim...
# 2  https://www.ted.com/talks/majora_carter_s_tale...
#
#                       headline  \
# 0  Averting the climate crisis
# 1             Simplicity sells
# 2          Greening the ghetto
#
#                                          description    event duration  \
# 0  With the same humor and humanity he exuded in ...  TED2006  0:16:17
# 1  New York Times columnist David Pogue takes aim...  TED2006  0:21:26
# 2  In an emotionally charged talk, MacArthur-winn...  TED2006  0:18:36
#
#   published                                               tags  ...  \
# 0   6/27/06  alternative energy,cars,global issues,climate ...  ...
# 1   6/27/06  simplicity,entertainment,interface design,soft...  ...
# 2   6/27/06  MacArthur grant,cities,green,activism,politics...  ...
#
#    speaker2_introduction speaker2_profile speaker_3 speaker3_occupation  \
# 0                    NaN              NaN       NaN                 NaN
# 1                    NaN              NaN       NaN                 NaN
# 2                    NaN              NaN       NaN                 NaN
#
#   speaker3_introduction speaker3_profile speaker_4 speaker4_occupation  \
# 0                   NaN              NaN       NaN                 NaN
# 1                   NaN              NaN       NaN                 NaN
# 2                   NaN              NaN       NaN                 NaN
#
#   speaker4_introduction speaker4_profile
# 0                   NaN              NaN
# 1                   NaN              NaN
# 2                   NaN              NaN
#
# [3 rows x 28 columns]

# %%
df_plus.insert(0, 'Set', 'plus')
df_plus.head(3)
# Out:
#     Set  Unnamed: 0  Talk_ID  \
# 0  plus           0       37
# 1  plus           1       47
# 2  plus           2       98
#
#                                           public_url  \
# 0  https://www.ted.com/talks/jimmy_wales_on_the_b...
# 1  https://www.ted.com/talks/david_deutsch_on_our...
# 2  https://www.ted.com/talks/richard_dawkins_on_o...
#
#                                       headline  \
# 0                       The birth of Wikipedia
# 1  Chemical scum that dream of distant quasars
# 2            Why the universe seems so strange
#
#                                          description           event duration  \
# 0  Jimmy Wales recalls how he assembled "a ragtag...  TEDGlobal 2005  0:20:01
# 1  Legendary scientist David Deutsch puts theoret...  TEDGlobal 2005  0:19:00
# 2  Biologist Richard Dawkins makes a case for "th...  TEDGlobal 2005  0:21:56
#
#   published                                               tags  ...  \
# 0   8/21/06  wikipedia,open-source,media,invention,culture,...  ...
# 1   9/12/06  cosmos,physics,global issues,climate change,un...  ...
# 2   9/12/06  cosmos,evolution,physics,astronomy,psychology,...  ...
#
#    speaker2_introduction speaker2_profile speaker_3 speaker3_occupation  \
# 0                    NaN              NaN       NaN                 NaN
# 1                    NaN              NaN       NaN                 NaN
# 2                    NaN              NaN       NaN                 NaN
#
#   speaker3_introduction speaker3_profile speaker_4 speaker4_occupation  \
# 0                   NaN              NaN       NaN                 NaN
# 1                   NaN              NaN       NaN                 NaN
# 2                   NaN              NaN       NaN                 NaN
#
#   speaker4_introduction speaker4_profile
# 0                   NaN              NaN
# 1                   NaN              NaN
# 2                   NaN              NaN
#
# [3 rows x 28 columns]

# %% [markdown]
# And now to merge the two dataframes. If all goes well, we should have a dataframe with a size of `1747 x 28`.

# %%
df_all = pd.concat([df_only, df_plus])
df_all.shape
# Out:
# (1747, 28)

# %% [markdown]
# Okay. Now let's check the contents, maybe trim that "Unnamed column", and then save this to a file. (To do this, I used `df_all.head(3)` and `df_all.tail(3)` several times to check the columns and the indexing. I also used `df_all = df_all.reset_index(drop=True)` to, well, reset the index.

# %%
df_all.tail(3)
# Out:
#        Set  Unnamed: 0  Talk_ID  \
# 1744  plus         755    12803
# 1745  plus         756    13062
# 1746  plus         757    12202
#
#                                              public_url  \
# 1744  https://www.ted.com/talks/sauti_sol_the_rhythm...
# 1745  https://www.ted.com/talks/mennat_el_ghalid_how...
# 1746  https://www.ted.com/talks/ndidi_nwuneli_the_ro...
#
#                                            headline  \
# 1744                         The rhythm of Afrobeat
# 1745        How fungi recognize (and infect) plants
# 1746  The role of faith and belief in modern Africa
#
#                                             description           event  \
# 1744  From Beyonc̩ to Drake and beyond, the world i...  TEDGlobal 2017
# 1745  Each year, the world loses enough food to feed...  TEDGlobal 2017
# 1746  Ndidi Nwuneli has advice for Africans who beli...  TEDGlobal 2017
#
#      duration published                                               tags  \
# 1744  0:12:25   3/23/18                    vocals,Africa,music,performance
# 1745  0:04:36   3/27/18  TED Fellows,fungi,nature,biology,biodiversity,...
# 1746  0:13:12   3/29/18  religion,faith,society,Africa,community,educat...
#
#       ...  speaker2_introduction speaker2_profile speaker_3  \
# 1744  ...                    NaN              NaN       NaN
# 1745  ...                    NaN              NaN       NaN
# 1746  ...                    NaN              NaN       NaN
#
#      speaker3_occupation speaker3_introduction speaker3_profile speaker_4  \
# 1744                 NaN                   NaN              NaN       NaN
# 1745                 NaN                   NaN              NaN       NaN
# 1746                 NaN                   NaN              NaN       NaN
#
#      speaker4_occupation speaker4_introduction speaker4_profile
# 1744                 NaN                   NaN              NaN
# 1745                 NaN                   NaN              NaN
# 1746                 NaN                   NaN              NaN
#
# [3 rows x 28 columns]

# %% [markdown]
# In order to remove the column which had the vestigial index, we need to see all the column names:

# %%
columns = df_all.columns.values.tolist()
print(columns)
# Out:
# ['Set', 'Unnamed: 0', 'Talk_ID', 'public_url', 'headline', 'description', 'event', 'duration', 'published', 'tags', 'views', 'text', 'speaker_1', 'speaker1_occupation', 'speaker1_introduction', 'speaker1_profile', 'speaker_2', 'speaker2_occupation', 'speaker2_introduction', 'speaker2_profile', 'speaker_3', 'speaker3_occupation', 'speaker3_introduction', 'speaker3_profile', 'speaker_4', 'speaker4_occupation', 'speaker4_introduction', 'speaker4_profile']

# %% [markdown]
# Now that we know the exact name of the column, we can drop it:

# %%
df_all_dropped = df_all.drop('Unnamed: 0', 1)

# %% [markdown]
# And, of course, a quick double-check to make sure everything is as it should be:

# %%
df_all_dropped.tail(3)
# Out:
#        Set  Talk_ID                                         public_url  \
# 1744  plus    12803  https://www.ted.com/talks/sauti_sol_the_rhythm...
# 1745  plus    13062  https://www.ted.com/talks/mennat_el_ghalid_how...
# 1746  plus    12202  https://www.ted.com/talks/ndidi_nwuneli_the_ro...
#
#                                            headline  \
# 1744                         The rhythm of Afrobeat
# 1745        How fungi recognize (and infect) plants
# 1746  The role of faith and belief in modern Africa
#
#                                             description           event  \
# 1744  From Beyonc̩ to Drake and beyond, the world i...  TEDGlobal 2017
# 1745  Each year, the world loses enough food to feed...  TEDGlobal 2017
# 1746  Ndidi Nwuneli has advice for Africans who beli...  TEDGlobal 2017
#
#      duration published                                               tags  \
# 1744  0:12:25   3/23/18                    vocals,Africa,music,performance
# 1745  0:04:36   3/27/18  TED Fellows,fungi,nature,biology,biodiversity,...
# 1746  0:13:12   3/29/18  religion,faith,society,Africa,community,educat...
#
#        views  ... speaker2_introduction speaker2_profile speaker_3  \
# 1744  195195  ...                   NaN              NaN       NaN
# 1745  811626  ...                   NaN              NaN       NaN
# 1746  662380  ...                   NaN              NaN       NaN
#
#      speaker3_occupation speaker3_introduction speaker3_profile speaker_4  \
# 1744                 NaN                   NaN              NaN       NaN
# 1745                 NaN                   NaN              NaN       NaN
# 1746                 NaN                   NaN              NaN       NaN
#
#      speaker4_occupation speaker4_introduction speaker4_profile
# 1744                 NaN                   NaN              NaN
# 1745                 NaN                   NaN              NaN
# 1746                 NaN                   NaN              NaN
#
# [3 rows x 27 columns]

# %% [markdown]
# And let's write this to a `csv` and get on with the analysis.

# %%
df_all_dropped.to_csv('../data/TEDall_speakers.csv', index=False)

# %% [markdown]
# ## Loading the New Dataframe.

# %% [markdown]
# Loading the new dataframe.

# %%
df = pd.read_csv('../output/TEDall_speakers.csv')
df.shape

# %%
df.dtypes
