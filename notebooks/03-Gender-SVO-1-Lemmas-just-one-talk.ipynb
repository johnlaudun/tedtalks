# %% [markdown]
# # SVO Verbs  Lemmatized
#
# Initial note on lemmatizing: https://stackoverflow.com/questions/51658153/lemmatize-a-doc-with-spacy

# %%
# IMPORTS
import re, spacy, textacy
import pandas as pd

# DATA LOAD
# Loading the Data in a gendered partitioned fashion: 
talks_m = pd.read_csv('../output/talks_male.csv', index_col='Talk_ID')
talks_f = pd.read_csv('../output/talks_female.csv', index_col='Talk_ID')
talks_nog = pd.read_csv('../output/talks_nog.csv', index_col='Talk_ID')
talks_all = pd.concat([talks_m, talks_f, talks_nog])

# GETTING JUST THE TEXTS
texts_all = talks_all.text.tolist()
texts_women = talks_f.text.tolist()
texts_men = talks_m.text.tolist()

# Lowercase everything before we create spaCy doc and Textacy SVO triple
texts_w = [text.lower() for text in texts_women]
texts_m = [text.lower() for text in texts_men]

# %% [markdown]
# ## From Texts to SVOs

# %%
# Load the Space pipeline to be used
nlp = spacy.load('en_core_web_sm')
# nlp.add_pipe('sentencizer')
# nlp.remove_pipe("lemmatizer")
# nlp.add_pipe("lemmatizer", config={"mode": "lookup"}).initialize()

# %%
# Use the pipe method to feed documents 
docs_w = list(nlp.pipe(texts_w))
docs_m = list(nlp.pipe(texts_m))

# A quick check of our work:
docs_m[0]._.preview
# Out:
# 'Doc(2690 tokens: "  thank you so much, chris. and it\'s truly a gr...")'

# %% [markdown]
# According to the [iPython documentation](https://ipython.readthedocs.io/en/stable/config/extensions/storemagic.html), we can `%store` variables so that if the notebook crashes, we need not run the code above again.

# %%
#%store docs_w docs_m
# Out:
# Stored 'docs_w' (list)
# Stored 'docs_m' (list)

# %%
lemmatas = [token.lemma_ for token in docs_m[0]]
print(lemmatas)
# Out:
# ['  ', 'thank', 'you', 'so', 'much', ',', 'chris', '.', 'and', 'it', 'be', 'truly', 'a', 'great', 'honor', 'to', 'have', 'the', 'opportunity', 'to', 'come', 'to', 'this', 'stage', 'twice', ';', 'I', 'be', 'extremely', 'grateful', '.', 'I', 'have', 'be', 'blow', 'away', 'by', 'this', 'conference', ',', 'and', 'I', 'want', 'to', 'thank', 'all', 'of', 'you', 'for', 'the', 'many', 'nice', 'comment', 'about', 'what', 'I', 'have', 'to', 'say', 'the', 'other', 'night', '.', 'and', 'I', 'say', 'that', 'sincerely', ',', 'partly', 'because', '(', 'mock', 'sob', ')', 'I', 'need', 'that', '.', '   ', '(', 'laughter', ')', '   ', 'put', 'yourselves', 'in', 'my', 'position', '.', '   ', '(', 'laughter', ')', '   ', 'I', 'fly', 'on', 'air', 'force', 'two', 'for', 'eight', 'year', '.', '   ', '(', 'laughter', ')', '   ', 'now', 'I', 'have', 'to', 'take', 'off', 'my', 'shoe', 'or', 'boot', 'to', 'get', 'on', 'an', 'airplane', '!', '   ', '(', 'laughter', ')', '   ', '(', 'applause', ')', '   ', 'I', 'will', 'tell', 'you', 'one', 'quick', 'story', 'to', 'illustrate', 'what', 'that', 'be', 'be', 'like', 'for', 'I', '.', '   ', '(', 'laughter', ')', '   ', 'it', 'be', 'a', 'true', 'story', '—', 'every', 'bit', 'of', 'this', 'be', 'true', '.', '   ', 'soon', 'after', 'tipper', 'and', 'I', 'leave', 'the', '—', '(', 'mock', 'sob', ')', 'white', 'house', '—', '   ', '(', 'laughter', ')', '   ', 'we', 'be', 'drive', 'from', 'our', 'home', 'in', 'nashville', 'to', 'a', 'little', 'farm', 'we', 'have', '50', 'mile', 'east', 'of', 'nashville', '.', 'drive', 'ourselves', '.', '   ', '(', 'laughter', ')', '   ', 'I', 'know', 'it', 'sound', 'like', 'a', 'little', 'thing', 'to', 'you', ',', 'but', '—', '   ', '(', 'laughter', ')', '   ', 'I', 'look', 'in', 'the', 'rear', '-', 'view', 'mirror', 'and', 'all', 'of', 'a', 'sudden', 'it', 'just', 'hit', 'I', '.', 'there', 'be', 'no', 'motorcade', 'back', 'there', '.', '   ', '(', 'laughter', ')', '   ', 'you', "'ve", 'hear', 'of', 'phantom', 'limb', 'pain', '?', '   ', '(', 'laughter', ')', '   ', 'this', 'be', 'a', 'rent', 'ford', 'taurus', '.', '   ', '(', 'laughter', ')', '   ', 'it', 'be', 'dinnertime', ',', 'and', 'we', 'start', 'look', 'for', 'a', 'place', 'to', 'eat', '.', 'we', 'be', 'on', 'i-40', '.', 'we', 'get', 'to', 'exit', '238', ',', 'lebanon', ',', 'tennessee', '.', 'we', 'get', 'off', 'the', 'exit', ',', 'we', 'find', 'a', 'shoney', "'s", 'restaurant', '.', 'low', '-', 'cost', 'family', 'restaurant', 'chain', ',', 'for', 'those', 'of', 'you', 'who', 'do', 'not', 'know', 'it', '.', 'we', 'go', 'in', 'and', 'sit', 'down', 'at', 'the', 'booth', ',', 'and', 'the', 'waitress', 'come', 'over', ',', 'make', 'a', 'big', 'commotion', 'over', 'tipper', '.', '   ', '(', 'laughter', ')', '   ', 'she', 'take', 'our', 'order', ',', 'and', 'then', 'go', 'to', 'the', 'couple', 'in', 'the', 'booth', 'next', 'to', 'we', ',', 'and', 'she', 'lower', 'her', 'voice', 'so', 'much', ',', 'I', 'have', 'to', 'really', 'strain', 'to', 'hear', 'what', 'she', 'be', 'say', '.', 'and', 'she', 'say', '"', 'yes', ',', 'that', 'be', 'former', 'vice', 'president', 'al', 'gore', 'and', 'his', 'wife', ',', 'tipper', '.', '"', 'and', 'the', 'man', 'say', ',', '"', 'he', 'be', 'come', 'down', 'a', 'long', 'way', ',', 'have', 'not', 'he', '?', '"', '   ', '(', 'laughter', ')', '   ', '(', 'applause', ')', '   ', 'there', 'be', 'be', 'kind', 'of', 'a', 'series', 'of', 'epiphany', '.', '   ', '(', 'laughter', ')', '   ', 'the', 'very', 'next', 'day', ',', 'continue', 'the', 'totally', 'true', 'story', ',', 'I', 'get', 'on', 'a', 'g', '-', 'v', 'to', 'fly', 'to', 'africa', 'to', 'make', 'a', 'speech', 'in', 'nigeria', ',', 'in', 'the', 'city', 'of', 'lago', ',', 'on', 'the', 'topic', 'of', 'energy', '.', 'and', 'I', 'begin', 'the', 'speech', 'by', 'tell', 'they', 'the', 'story', 'of', 'what', 'have', 'just', 'happen', 'the', 'day', 'before', 'in', 'nashville', '.', 'and', 'I', 'tell', 'it', 'pretty', 'much', 'the', 'same', 'way', 'I', "'ve ...

# %%
lemmas = [token.lemma_ for token in docs_w[0]]

# %%
lemmas_w = []
for doc in docs_w:
    lemmas = [token.lemma_ for token in doc]
    lemmas_w.append(lemmas)

# %%
len(lemmas_w)
# Out:
# 260

# %%
lemmas_m = []
for doc in docs_m:
    lemmas = [token.lemma_ for token in doc]
    lemmas_m.append(lemmas)

# %%
' '.join(lemmas_m[0][0:100])
# Out:
# '   thank you so much , chris . and it be truly a great honor to have the opportunity to come to this stage twice ; I be extremely grateful . I have be blow away by this conference , and I want to thank all of you for the many nice comment about what I have to say the other night . and I say that sincerely , partly because ( mock sob ) I need that .     ( laughter )     put yourselves in my position .     ( laughter )     I fly on air force'

# %%
joined = ' '.join(lemmas_m[0])

# %%
z_svos = list(textacy.extract.triples.subject_verb_object_triples(joined))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [57], in <module>
# ----> 1 z_svos = list(textacy.extract.triples.subject_verb_object_triples(joined))
#
# File /opt/anaconda3/envs/tedtalks/lib/python3.9/site-packages/textacy/extract/triples.py:69, in subject_verb_object_triples(doclike)
#      67     sents = [doclike]
#      68 else:
# ---> 69     sents = doclike.sents
#      71 for sent in sents:
#      72     # connect subjects/objects to direct verb heads
#      73     # and expand them to include conjuncts, compound nouns, ...
#      74     verb_sos: Mapping = collections.defaultdict(
#      75         lambda: collections.defaultdict(set)
#      76     )
#
# AttributeError: 'str' object has no attribute 'sents'

# %%
lemmas = [token.lemma_ for token in texts_m[0]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [58], in <module>
# ----> 1 lemmas = [token.lemma_ for token in texts_m[0]]
#
# Input In [58], in <listcomp>(.0)
# ----> 1 lemmas = [token.lemma_ for token in texts_m[0]]
#
# AttributeError: 'str' object has no attribute 'lemma_'

# %% [markdown]
# ## SVOs to Dataframe
#
# Since we create SVOs for every sentence in the two subcorpora, why not save both to two dataframes?

# %%
def createSVOs(doc, svo_list):
    # Create the list of tuples for the document
    svotriples = list(textacy.extract.triples.subject_verb_object_triples(doc))
    # Convert to list of dictionaries
    for item in svotriples:
        svo_list.append(
            {
                'subject': str(item[0][-1]), 
                'verb': str(item[1][-1]), 
                'object': str(item[2])
            }
        )

# %%
def createSVOs_by_talk(doc, all_svo_list):
    # Create the list of tuples for the document
    svotriples = list(textacy.extract.triples.subject_verb_object_triples(doc))
    # Convert to list of dictionaries
    talk_list = []
    for item in svotriples:
        talk_list.append(
            {
                'subject': str(item[0][-1]), 
                'verb': str(item[1][-1]), 
                'object': str(item[2])
            }
        )
    all_svo_list.append(talk_list)

# %%
def createSVOs_tID(doc, svo_list, talkID=None):
    # Create the list of tuples for the document
    svotriples = list(textacy.extract.triples.subject_verb_object_triples(doc))
    # Convert to list of dictionaries
    for item in svotriples:
        svo_list.append(
            {
                'subject': str(item[0][-1]), 
                'verb': str(item[1][-1]), 
                'object': str(item[2]),
                'TalkID':talkID
            }
        )

# %% [markdown]
# ### A Small Experiment to get to Lemmas
#
# With Z standing in for *docs_m[0]* above, which is Al Gore's TED talk, we are trying to get the lemma of the verbs in the SVOs.

# %%
Zsvos = list(textacy.extract.triples.subject_verb_object_triples(docs_m[0]))

# %%
print(Zsvos[0:5])
# Out:
# [SVOTriple(subject=[i], verb=[have, been, blown], object=[conference]), SVOTriple(subject=[i], verb=[want], object=[to, thank, all, of, you, for, the, many, nice, comments, about, what, i, had, to, say, the, other, night]), SVOTriple(subject=[i], verb=[need], object=[that]), SVOTriple(subject=[laughter], verb=[put], object=[yourselves]), SVOTriple(subject=[i], verb=[flew], object=[two])]

# %%
# %store Zsvos >Zsvos.txt
# Out:
# Writing 'Zsvos' (list) to file 'Zsvos.txt'.

# %%
Z = pd.DataFrame(Zsvos)
Z.shape
# Out:
# (117, 3)

# %%
def lemmatize(item):
    token = str(item[1][-1])
    lemma = token.lemma_
    return lemma

# %%
type(Zsvos[0])
# Out:
# textacy.extract.triples.SVOTriple

# %%
Z['verb'] = Z['verb'].apply(lemmatize)

# %% [markdown]
# ### Now at Scale

# %%
# Create the two lists
svos_m = []
svos_w = []

# Populate the lists with SVO triples
for doc in docs_m:
    createSVOs(doc, svos_m)

for doc in docs_w:
    createSVOs(doc, svos_w)

# %%
# Convert the lists to dataframes
svos_w = pd.DataFrame(svos_w)
svos_m = pd.DataFrame(svos_m)

print(svos_m.shape[0], svos_w.shape[0])
# Out:
# 80550 26610

# %%
svos_m
# Out:
#         subject     verb                                             object
# 0             i    blown                                       [conference]
# 1             i     want  [to, thank, all, of, you, for, the, many, nice...
# 2             i     need                                             [that]
# 3      laughter      put                                       [yourselves]
# 4             i     have  [to, take, off, my, shoes, or, boots, to, get,...
# ...         ...      ...                                                ...
# 80545       you  imagine                                              [him]
# 80546       you      see                                   [credit, rating]
# 80547        we       do                                             [what]
# 80548        it   expose                                         [humanity]
# 80549        it   reveal                                           [demons]
#
# [80550 rows x 3 columns]

# %%
# Get talkIDs in order
m_talkIDs = talks_m.index.values.tolist()
w_talkIDs = talks_f.index.values.tolist()

# %%
# Out:
# 720

# %%
# Create the two lists
svos_m_by_talk = []
svos_w_by_talk = []

# Populate the lists with SVO triples
for m in range(len(m_talkIDs)):
    doc = docs_m[m]
    talkID = m_talkIDs[m]
    createSVOs_tID(doc, svos_m_by_talk, talkID)

for w in range(len(w_talkIDs)):
    doc = docs_w[w]
    talkID = w_talkIDs[w]
    createSVOs_tID(doc, svos_w_by_talk, talkID)

# %%
svos_m_by_talk
# Out:
# [{'subject': 'i', 'verb': 'blown', 'object': '[conference]', 'TalkID': 1},
#  {'subject': 'i',
#   'verb': 'want',
#   'object': '[to, thank, all, of, you, for, the, many, nice, comments, about, what, i, had, to, say, the, other, night]',
#   'TalkID': 1},
#  {'subject': 'i', 'verb': 'need', 'object': '[that]', 'TalkID': 1},
#  {'subject': 'laughter', 'verb': 'put', 'object': '[yourselves]', 'TalkID': 1},
#  {'subject': 'i',
#   'verb': 'have',
#   'object': '[to, take, off, my, shoes, or, boots, to, get, on, an, airplane]',
#   'TalkID': 1},
#  {'subject': 'i', 'verb': 'tell', 'object': '[story]', 'TalkID': 1},
#  {'subject': 'i', 'verb': 'left', 'object': '[white, house]', 'TalkID': 1},
#  {'subject': 'i', 'verb': 'looked', 'object': '[me]', 'TalkID': 1},
#  {'subject': 'it', 'verb': 'hit', 'object': '[me]', 'TalkID': 1},
#  {'subject': 'we',
#   'verb': 'started',
#   'object': '[looking, for, a, place, to, eat]',
#   'TalkID': 1},
#  {'subject': 'we',
#   'verb': 'got',
#   'object': '[to, exit, 238, ,, lebanon, ,, tennessee]',
#   'TalkID': 1},
#  {'subject': 'we', 'verb': 'found', 'object': '[restaurant]', 'TalkID': 1},
#  {'subject': 'who', 'verb': 'know', 'object': '[it]', 'TalkID': 1},
#  {'subject': 'we', 'verb': 'went', 'object': '[commotion]', 'TalkID': 1},
#  {'subject': 'waitress', 'verb': 'sat', 'object': '[commotion]', 'TalkID': 1},
#  {'subject': 'waitress', 'verb': 'came', 'object': '[commotion]', 'TalkID': 1},
#  {'subject': 'we', 'verb': 'made', 'object': '[commotion]', 'TalkID': 1},
#  {'subject': 'she', 'verb': 'took', 'object': '[order]', 'TalkID': 1},
#  {'subject': 'she', 'verb': 'went', 'object': '[order, voice]', 'TalkID': 1},
#  {'subject': 'she', 'verb': 'lowered', 'object': '[voice]', 'TalkID': 1},
#  {'subject': 'i',
#   'verb': 'had',
#   'object': '[to, really, strain, to, hear, what, she, was, saying]',
#   'TalkID': 1},
#  {'subject': 'she', 'verb': 'saying', 'object': '[what]', 'TalkID': 1},
#  {'subject': 'i',
#   'verb': 'got',
#   'object': '[to, fly, to, africa, to, make, a, speech, in, nigeria, ,, in, the, city, of, lagos, ,, on, the, topic, of, energy]',
#   'TalkID': 1},
#  {'subject': 'i', 'verb': 'began', 'object': '[speech]', 'TalkID': 1},
#  {'subject': 'i', 'verb': 'told', 'object': '[it]', 'TalkID': 1},
#  {'subject': 'i', 'verb': 'shared', 'object': '[it]', 'TalkID': 1},
#  {'subject': 'i', 'verb': 'driving', 'object': '[ourselves]', 'TalkID': 1},
#  {'subject': 'man', 'verb': 'said', 'object': '[what]', 'TalkID': 1},
#  {'subject': 'i', 'verb': 'gave', 'object': '[speech]', 'TalkID': 1},
#  {'subject': 'they', 'verb': 'opened', 'object': '[door]', 'TalkID': 1},
#  {'subject': 'he', 'verb': 'waving', 'object': '[piece]', 'TalkID': 1},
#  {'subject': 'he',
#   'verb': 'yelling',
#   'object': '[call, washington]',
#   'TalkID': 1},
#  {'subject': 'it', 'verb': 'turned', 'object': '[to, be]', 'TalkID': 1},
#  {'subject': 'one', 'verb': 'written', 'object': '[story]', 'TalkID': 1},
#  {'subject': 'it', 'verb': 'printed', 'object': '[story]', 'TalkID': 1},
#  {'subject': 'story', 'verb': 'began', 'object': '[it]', 'TalkID': 1},
#  {'subject': 'i',
#   'verb': 'opened',
#   'object': '[cost, family, restaurant]',
#   'TalkID': 1},
#  {'subject': 'we', 'verb': 'running', 'object': '[it]', 'TalkID': 1},
#  {'subject': 'one', 'verb': 'had', 'object': '[me]', 'TalkID': 1},
#  {'subject': 'tipper', 'verb': 'saying', 'object': '[burger]', 'TalkID': 1},
#  {'subject': 'i', 'verb': 'got', 'object': '[letter]', 'TalkID': 1},
#  {'subject': 'we',
#   'verb': 'like',
#   'object': "[to, celebrate, each, other, 's, successes, in, life]",
#   'TalkID': 1},
#  {'subject': 'i',
#   'verb': 'going',
#   'object': '[to, talk, about, information, ecology]',
#   'TalkID': 1},
#  {'subject': 'i',
#   'verb': 'plan',
#   'object': '[to, make, a, lifelong, habit, of, coming, back, to, ted]',
#   'TalkID': 1},
#  {'subject': 'i',
#   'verb': 'want',
#   'object': '[to, focus, on, what, many, of, you, have, said, you, would, like, me, to, elaborate, on]',
#   'TalkID': 1},
#  {'subject': 'you', 'verb': 'like', 'object': '[what]', 'TalkID': 1},
#  {'subject': 'you', 'verb': 'do', 'object': '[what]', 'TalkID': 1},
#  {'subject': 'i',
#   'verb': 'want',
#   'object': '[to, start, with, a, couple, of]',
#   'TalkID': 1},
#  {'subject': 'i',
#   'verb': 'going',
#   'object': '[to, show, some, new, images]',
#   'TalkID': 1},
#  {'subject': 'i',
#   'verb': 'going',
#   'object': '[to, recapitulate, just, four, or, five]',
#   'TalkID': 1},
#  {'subject': 'i', 'verb': 'update', 'object': '[slide, show]', 'TalkID': 1},
#  {'subject': 'i', 'verb': 'give', 'object': '[it]', 'TalkID': 1},
#  {'subject': 'i', 'verb': 'add', 'object': '[images]', 'TalkID': 1},
#  {'subject': 'i', 'verb': 'learn', 'object': '[more]', 'TalkID': 1},
#  {'subject': 'i', 'verb': 'give', 'object': '[it]', 'TalkID': 1},
#  {'subject': 'you', 'verb': 'find', 'object': '[shells]', 'TalkID': 1},
#  {'subject': 'we',
#   'verb': 'got',
#   'object': '[temperature, records]',
#   'TalkID': 1},
#  {'subject': 'you', 'verb': 'wanted', 'object': '[news]', 'TalkID': 1},
#  {'subject': 'i',
#   'verb': 'going',
#   'object': '[to, go, into, new, material, about, what, you, can, do]',
#   'TalkID': 1},
#  {'subject': 'i',
#   'verb': 'wanted',
#   'object': '[to, elaborate, on, a, couple, of, these]',
#   'TalkID': 1},
#  {'subject': 'we',
#   'verb': 'projected',
#   'object': '[to, go, with, the, u.s, ., contribution, to, global, warming, ,, under, business, as, usual]',
#   'TalkID': 1},
#  {'subject': 'you', 'verb': 'put', 'object': '[it]', 'TalkID': 1},
#  {'subject': 'we', 'verb': 'have', 'object': '[standards]', 'TalkID': 1},
#  {'subject': 'we', 'verb': 'address', 'object': '[that]', 'TalkID': 1},
#  {'subject': 'renewables',
#   'verb': 'make',
#   'object': '[difference]',
#   'TalkID': 1},
#  {'subject': 'wedge',
#   'verb': 'going',
#   'object': '[to, grow, much, more, rapidly]',
#   'TalkID': 1},
#  {'subject': 'projection', 'verb': 'shows', 'object': '[it]', 'TalkID': 1},
#  {'subject': 'that', 'verb': 'enable', 'object': '[us]', 'TalkID': 1},
#  {'subject': 'you', 'verb': 'do', 'object': '[what]', 'TalkID': 1},
#  {'subject': 'i', 'verb': 'mentioned', 'object': '[automobiles]', 'TalkID': 1},
#  {'subject': 'i', 'verb': 'buy', 'object': '[hybrid]', 'TalkID': 1},
#  {'subject': 'you', 'verb': 'have', 'object': '[choices]', 'TalkID': 1},
#  {'subject': 'that',
#   'verb': 'have',
#   'object': '[effect, effect]',
#   'TalkID': 1},
#  {'subject': 'this', 'verb': 'make', 'object': '[decision]', 'TalkID': 1},
#  {'subject': 'i',
#   'verb': 'love',
#   'object': '[to, get, your, advice, and, help, on, how, to, say, this, in, a, way, that, connects, with, the, most, people]',
#   'TalkID': 1},
#  {'subject': 'lot', 'verb': 'made', 'object': '[decision]', 'TalkID': 1},
#  {'subject': 'it',
#   'verb': 'means',
#   'object': '[reduce, your, carbon, dioxide, emissions, with, the, full, range, of, choices, that, you, make, ,, and, then, purchase, or, acquire, offsets, for, the, remainder, that, you, have, not, completely, reduced]',
#   'TalkID': 1},
#  {'subject': 'you', 'verb': 'make', 'object': '[that]', 'TalkID': 1},
#  {'subject': 'you', 'verb': 'reduced', 'object': '[that]', 'TalkID': 1},
#  {'subject': 'it', 'verb': 'means', 'object': '[what]', 'TalkID': 1},
#  {'subject': 'you', 'verb': 'calculate', 'object': '[options]', 'TalkID': 1},
#  {'subject': 'you', 'verb': 'given', 'object': '[options]', 'TalkID': 1},
#  {'subject': 'this', 'verb': 'updated', 'object': '[purchases]', 'TalkID': 1},
#  {'subject': 'we', 'verb': 'have', 'object': '[purchases]', 'TalkID': 1},
#  {'subject': 'some', 'verb': 'done', 'object': '[that]', 'TalkID': 1},
#  {'subject': 'majora', 'verb': 'mentioned', 'object': '[this]', 'TalkID': 1},
#  {'subject': 'you', 'verb': 'invested', 'object': '[money]', 'TalkID': 1},
#  {'subject': 'you', 'verb': 'compensate', 'object': '[who]', 'TalkID': 1},
#  {'subject': 'you', 'verb': 'pay', 'object': '[them]', 'TalkID': 1},
#  {'subject': 'they',
#   'verb': 'going',
#   'object': "[how, much, to, get, paid, on, your, capital, that, they, 've, invested, ,, based, on, the, short, -, term, returns]",
#   'TalkID': 1},
#  {'subject': 'they', 'verb': 'invested', 'object': '[that]', 'TalkID': 1},
#  {'subject': 'you',
#   'verb': 'going',
#   'object': '[to, get, short, -, term, decisions]',
#   'TalkID': 1},
#  {'subject': 'many', 'verb': 'have', 'object': '[opportunity]', 'TalkID': 1},
#  {'subject': 'lot', 'verb': 'see', 'object': '[it]', 'TalkID': 1},
#  {'subject': 'i',
#   'verb': 'going',
#   'object': '[to, train, people, to, give, this, slideshow, —, re]',
#   'TalkID': 1},
#  {'subject': 'they', 'verb': 'mean', 'object': '[what]', 'TalkID': 1},
#  {'subject': 'i',
#   'verb': 'going',
#   'object': '[to, be, conducting, a, course, this, summer, for, a, group, of, people, that, are, nominated, by, different, folks, to, come]',
#   'TalkID': 1},
#  {'subject': 'that',
#   'verb': 'nominated',
#   'object': '[folks, to, come]',
#   'TalkID': 1},
#  {'subject': 'i', 'verb': 'give', 'object': '[masse]', 'TalkID': 1},
#  {'subject': 'we',
#   'verb': 'going',
#   'object': '[to, update, the, slideshow, for, all, of, them, every, single, week, ,, to, keep, it, right, on, the, cutting, edge]',
#   'TalkID': 1},
#  {'subject': 'people', 'verb': 'remix', 'object': '[it]', 'TalkID': 1},
#  {'subject': 'people', 'verb': 'do', 'object': '[it]', 'TalkID': 1},
#  {'subject': 'anybody', 'verb': 'get', 'object': '[idea]', 'TalkID': 1},
#  {'subject': 'i',
#   'verb': 'trying',
#   'object': '[to, convince, you, to, be, a, democrat]',
#   'TalkID': 1},
#  {'subject': 'we', 'verb': 'need', 'object': '[republicans]', 'TalkID': 1},
#  {'subject': 'this',
#   'verb': 'used',
#   'object': '[to, be, a, bipartisan, issue]',
#   'TalkID': 1},
#  {'subject': 'i',
#   'verb': 'know',
#   'object': '[to, be, a, bipartisan, issue]',
#   'TalkID': 1},
#  {'subject': 'democracy', 'verb': 'work', 'object': '[way]', 'TalkID': 1},
#  {'subject': 'it', 'verb': 'supposed', 'object': '[to, work]', 'TalkID': 1},
#  {'subject': 'you', 'verb': 'have', 'object': '[liability]', 'TalkID': 1},
#  {'subject': 'you', 'verb': 'urge', 'object': '[ceo]', 'TalkID': 1},
#  {'subject': 'market',
#   'verb': 'work',
#   'object': '[to, solve, this, problem]',
#   'TalkID': 1},
#  {'subject': 'we', 'verb': 'accomplish', 'object': '[this]', 'TalkID': 1},
#  {'subject': 'we',
#   'verb': 'have',
#   'object': '[to, change, the, minds, of, the, american, people]',
#   'TalkID': 1},
#  {'subject': 'politicians',
#   'verb': 'have',
#   'object': '[permission]',
#   'TalkID': 1},
#  {'subject': 'what', 'verb': 'needs', 'object': '[to, be, done]', 'TalkID': 1},
#  {'subject': 'role',
#   'verb': 'includes',
#   'object': '[mediating, between, wealth, and, power, the, way, it, once, did]',
#   'TalkID': 1},
#  {'subject': 'we',
#   'verb': 'have',
#   'object': '[to, buy, a, lot, of, those, ads]',
#   'TalkID': 1},
#  {'subject': "'s", 'verb': 're', 'object': '[warming]', 'TalkID': 1},
#  {'subject': 'i', 'verb': 'like', 'object': '[climate, crisis]', 'TalkID': 1},
#  {'subject': 'i', 'verb': 'need', 'object': '[help]', 'TalkID': 1},
#  {'subject': 'somebody', 'verb': 'said', 'object': '[test]', 'TalkID': 1},
#  {'subject': 'scientist', 'verb': 'told', 'object': '[me]', 'TalkID': 1},
#  {'subject': 'you', 'verb': 'have', 'object': '[influence]', 'TalkID': 1},
#  {'subject': 'i', 'verb': 'appreciate', 'object': '[it]', 'TalkID': 1},
#  {'subject': 'i', 'verb': 'ignored', 'object': '[warning]', 'TalkID': 7},
#  {'subject': 'dinner', 'verb': 'grew', 'object': '[mold]', 'TalkID': 7},
#  {'subject': 'dinner', 'verb': 'grew', 'object': '[mold]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'punched', 'object': '[touch, tone]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'spent', 'object': '[hours]', 'TalkID': 7},
#  {'subject': 'software', 'verb': 'crashed', 'object': '[mac]', 'TalkID': 7},
#  {'subject': 'it', 'verb': 'erased', 'object': '[roms]', 'TalkID': 7},
#  {'subject': 'mac', 'verb': 'makes', 'object': '[sounds]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'call', 'object': '[9]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'pray', 'object': '[9]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'get', 'object': '[me]', 'TalkID': 7},
#  {'subject': 'music', 'verb': 'thank', 'object': '[you]', 'TalkID': 7},
#  {'subject': 'who',
#   'verb': 'used',
#   'object': '[to, be, a, broadway, accompanist]',
#   'TalkID': 7},
#  {'subject': 'i', 'verb': 'offered', 'object': '[times, column]', 'TalkID': 7},
#  {'subject': 'you',
#   'verb': 'sent',
#   'object': '[coolest, hottest, slickest]',
#   'TalkID': 7},
#  {'subject': 'you',
#   'verb': 'get',
#   'object': '[to, try, them, out, ,]',
#   'TalkID': 7},
#  {'subject': 'you',
#   'verb': 'play',
#   'object': '[to, try, them, out, ,, them]',
#   'TalkID': 7},
#  {'subject': 'you', 'verb': 'evaluate', 'object': '[them]', 'TalkID': 7},
#  {'subject': 'you',
#   'verb': 'have',
#   'object': '[to, send, them, back]',
#   'TalkID': 7},
#  {'subject': 'you',
#   'verb': 'paid',
#   'object': '[to, try, them, out, ,, them]',
#   'TalkID': 7},
#  {'subject': 'i', 'verb': 'love', 'object': '[it]', 'TalkID': 7},
#  {'subject': 'job',
#   'verb': 'came',
#   'object': '[to, publish, my, email, address, at, the, end, of, every, column]',
#   'TalkID': 7},
#  {'subject': 'they',
#   'verb': 'intended',
#   'object': '[to, publish, my, email, address, at, the, end, of, every, column]',
#   'TalkID': 7},
#  {'subject': 'i', 'verb': 'noticed', 'object': '[what]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'get', 'object': '[amount]', 'TalkID': 7},
#  {'subject': 'you',
#   'verb': 'get',
#   'object': '[hundreds, hundreds, hundreds]',
#   'TalkID': 7},
#  {'subject': 'i', 'verb': 'getting', 'object': '[lot]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'see', 'object': '[it]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'wrote', 'object': '[column]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'call', 'object': '[it]', 'TalkID': 7},
#  {'subject': 'me', 'verb': 'tell', 'object': '[you]', 'TalkID': 7},
#  {'subject': 'whoever',
#   'verb': 'figures',
#   'object': '[how, to, make, money, off, of, this, frustration]',
#   'TalkID': 7},
#  {'subject': 'industry', 'verb': 'put', 'object': '[thought]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'show', 'object': '[you]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'mean', 'object': '[what]', 'TalkID': 7},
#  {'subject': 'interface', 'verb': 'used', 'object': '[what]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'put', 'object': '[mac]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'had', 'object': '[privilege]', 'TalkID': 7},
#  {'subject': 'guy', 'verb': 'had', 'object': '[headset]', 'TalkID': 7},
#  {'subject': 'they',
#   'verb': 'collect',
#   'object': '[user, stories]',
#   'TalkID': 7},
#  {'subject': 'they', 'verb': 'pass', 'object': '[them]', 'TalkID': 7},
#  {'subject': 'they', 'verb': 'do', 'object': '[which]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'have', 'object': '[copy]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'mean', 'object': '[what]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'tell', 'object': '[you]', 'TalkID': 7},
#  {'subject': 'it', 'verb': 'squeaks', 'object': '[it]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'move', 'object': '[it]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'got', 'object': '[mouse]', 'TalkID': 7},
#  {'subject': 'laughter',
#   'verb': 'said',
#   'object': '[click, here, to, continue]',
#   'TalkID': 7},
#  {'subject': 'you', 'verb': 'like', 'object': '[one]', 'TalkID': 7},
#  {'subject': 'we', 'verb': 'got', 'object': '[time]', 'TalkID': 7},
#  {'subject': 'computer',
#   'verb': 'crashed',
#   'object': '[technician]',
#   'TalkID': 7},
#  {'subject': 'he', 'verb': 'told', 'object': '[technician]', 'TalkID': 7},
#  {'subject': 'he', 'verb': 'restart', 'object': '[it]', 'TalkID': 7},
#  {'subject': 'he', 'verb': 'typed', 'object': '[11]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'typing', 'object': '[11, laughter]', 'TalkID': 7},
#  {'subject': 'message',
#   'verb': 'says',
#   'object': '[error, type, 11]',
#   'TalkID': 7},
#  {'subject': 'gadgets',
#   'verb': 'getting',
#   'object': '[tinier, tinier]',
#   'TalkID': 7},
#  {'subject': 'fingers', 'verb': 'staying', 'object': '[size]', 'TalkID': 7},
#  {'subject': 'it',
#   'verb': 'gets',
#   'object': '[to, be, more, and, more, of, a, challenge]',
#   'TalkID': 7},
#  {'subject': 'you', 'verb': 'buy', 'object': '[piece]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'own', 'object': '[it]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'pay', 'object': '[dues]', 'TalkID': 7},
#  {'subject': 'we', 'verb': 'added', 'object': '[features]', 'TalkID': 7},
#  {'subject': 'we', 'verb': 'sell', 'object': '[it]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'know', 'object': '[guy]', 'TalkID': 7},
#  {'subject': 'who', 'verb': 'spent', 'object': '[4,000]', 'TalkID': 7},
#  {'subject': 'companies', 'verb': 'make', 'object': '[percent]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'call', 'object': '[it]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'improve', 'object': '[piece]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'ruin', 'object': '[it]', 'TalkID': 7},
#  {'subject': 'microsoft',
#   'verb': 'did',
#   'object': '[experiment]',
#   'TalkID': 7},
#  {'subject': 'they',
#   'verb': 'said',
#   'object': '[well, ,, wait, a, minute]',
#   'TalkID': 7},
#  {'subject': 'we', 'verb': 'adding', 'object': '[features]', 'TalkID': 7},
#  {'subject': "'s",
#   'verb': 'create',
#   'object': '[word, processor]',
#   'TalkID': 7},
#  {'subject': 'one', 'verb': 'bought', 'object': '[it]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'call', 'object': '[this]', 'TalkID': 7},
#  {'subject': 'people',
#   'verb': 'like',
#   'object': '[to, surround, themselves, with, unnecessary, power]',
#   'TalkID': 7},
#  {'subject': 'they',
#   'verb': 'need',
#   'object': '[database, website]',
#   'TalkID': 7},
#  {'subject': 'i', 'verb': 'need', 'object': '[that]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'add', 'object': '[features]', 'TalkID': 7},
#  {'subject': 'they', 'verb': 'going', 'object': '[to, go]', 'TalkID': 7},
#  {'subject': 'you',
#   'verb': 'going',
#   'object': '[to, stick, them]',
#   'TalkID': 7},
#  {'subject': 'you', 'verb': 'have', 'object': '[design, tools]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'do', 'object': '[buttons]', 'TalkID': 7},
#  {'subject': 'you',
#   'verb': 'do',
#   'object': '[sliders, menus, sub, -, menus]',
#   'TalkID': 7},
#  {'subject': 'you', 'verb': 'have', 'object': '[that]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'opened', 'object': '[toolbars]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'have', 'object': '[to, type, in]', 'TalkID': 7},
#  {'subject': 'you',
#   'verb': 'have',
#   'object': '[to, do, two, dimensions]',
#   'TalkID': 7},
#  {'subject': 'word', 'verb': 'bulleting', 'object': '[lists]', 'TalkID': 7},
#  {'subject': 'word', 'verb': 'underlining', 'object': '[links]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'telling', 'object': '[you]', 'TalkID': 7},
#  {'subject': 'part',
#   'verb': 'knowing',
#   'object': '[when, to, use, which, one, of, these, features]',
#   'TalkID': 7},
#  {'subject': 'you',
#   'verb': 'need',
#   'object': '[that, to, collapse, the, choices]',
#   'TalkID': 7},
#  {'subject': 'they', 'verb': 'put', 'object': '[them]', 'TalkID': 7},
#  {'subject': 'applause', 'verb': 'thank', 'object': '[you]', 'TalkID': 7},
#  {'subject': 'i',
#   'verb': 'designed',
#   'object': '[dialogue, box]',
#   'TalkID': 7},
#  {'subject': 'microsoft', 'verb': 'have', 'object': '[approach]', 'TalkID': 7},
#  {'subject': 'approach',
#   'verb': 'tends',
#   'object': "[to, be, :, let, 's, break, it, down]",
#   'TalkID': 7},
#  {'subject': "'s", 'verb': 'break', 'object': '[it]', 'TalkID': 7},
#  {'subject': "'s", 'verb': 'click', 'object': '[to, continue]', 'TalkID': 7},
#  {'subject': 'laughter', 'verb': 'choose', 'object': '[letter]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'want', 'object': '[to, type]', 'TalkID': 7},
#  {'subject': 'we', 'verb': 'want', 'object': '[that, to, cross]', 'TalkID': 7},
#  {'subject': 'trash',
#   'verb': 'folder',
#   'object': '[label, things]',
#   'TalkID': 7},
#  {'subject': 'i',
#   'verb': 'beg',
#   'object': '[to, break, all, those, rules, if, they, violate, the, biggest, rule, of, all, ,, which, is, intelligence]',
#   'TalkID': 7},
#  {'subject': 'they', 'verb': 'violate', 'object': '[rule]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'mean', 'object': '[what]', 'TalkID': 7},
#  {'subject': 'i',
#   'verb': 'going',
#   'object': '[to, give, you, some, examples, where, intelligence, makes, something, not, consistent]',
#   'TalkID': 7},
#  {'subject': 'you', 'verb': 'buying', 'object': '[something]', 'TalkID': 7},
#  {'subject': 'you',
#   'verb': 'supposed',
#   'object': '[to, put, in, your, address]',
#   'TalkID': 7},
#  {'subject': 'you',
#   'verb': 'supposed',
#   'object': "[to, choose, what, country, you, 're, from]",
#   'TalkID': 7},
#  {'subject': 'we',
#   'verb': 'like',
#   'object': '[to, think, of, the, internet, as, a, global, village]',
#   'TalkID': 7},
#  {'subject': 'you',
#   'verb': 'have',
#   'object': '[to, scroll, ,, like, ,, seven, screensful, to, get, to, it]',
#   'TalkID': 7},
#  {'subject': 'one', 'verb': 'touched', 'object': '[windows, pc]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'shut', 'object': '[windows, pc]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'have', 'object': '[printer]', 'TalkID': 7},
#  {'subject': 'you',
#   'verb': 'want',
#   'object': '[to, print, one, copy, of, your, document, ,, in, page, order, ,, on, that, printer]',
#   'TalkID': 7},
#  {'subject': 'you', 'verb': 'see', 'object': '[this]', 'TalkID': 7},
#  {'subject': 'who', 'verb': 'embraced', 'object': '[cult]', 'TalkID': 7},
#  {'subject': 'i',
#   'verb': 'got',
#   'object': "[to, speak, to, palm, when, they, were, flying, high, in, the, ', 90s]",
#   'TalkID': 7},
#  {'subject': 'i', 'verb': 'met', 'object': '[one]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'do', 'object': '[what]', 'TalkID': 7},
#  {'subject': 'task', 'verb': 'takes', 'object': '[taps]', 'TalkID': 7},
#  {'subject': 'it',
#   'verb': 'has',
#   'object': '[to, be, redesigned]',
#   'TalkID': 7},
#  {'subject': 'i',
#   'verb': 'going',
#   'object': '[to, show, you, an, example, of, a, company, that, does, not, have, a, tap, counter]',
#   'TalkID': 7},
#  {'subject': 'that', 'verb': 'have', 'object': '[tap, counter]', 'TalkID': 7},
#  {'subject': 'you',
#   'verb': 'want',
#   'object': '[to, create, a, new, blank, document, in, word]',
#   'TalkID': 7},
#  {'subject': 'you', 'verb': 'get', 'object': '[document]', 'TalkID': 7},
#  {'subject': 'i',
#   'verb': 'want',
#   'object': '[to, just, stand, here, and, make, fun, of, microsoft]',
#   'TalkID': 7},
#  {'subject': 'bill', 'verb': 'gates', 'object': '[song]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'wrote', 'object': '[dos]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'put', 'object': '[software, ibm]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'got', 'object': '[profit]', 'TalkID': 7},
#  {'subject': 'they', 'verb': 'got', 'object': '[loss]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'write', 'object': '[code]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'getting', 'object': '[royalties]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'buy', 'object': '[box]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'sell', 'object': '[code]', 'TalkID': 7},
#  {'subject': 'company', 'verb': 'doing', 'object': '[r&d]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'keep', 'object': '[idea]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'doing', 'object': '[this]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'write', 'object': '[code]', 'TalkID': 7},
#  {'subject': 'that', 'verb': 'fits', 'object': '[world]', 'TalkID': 7},
#  {'subject': 'we',
#   'verb': 'entered',
#   'object': '[domination, mode]',
#   'TalkID': 7},
#  {'subject': 'you', 'verb': 'have', 'object': '[choice]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'buy', 'object': '[code]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'write', 'object': '[code]', 'TalkID': 7},
#  {'subject': 'they',
#   'verb': 'dying',
#   'object': '[to, throw, the, whole, thing, out, and, start, fresh]',
#   'TalkID': 7},
#  {'subject': 'that', 'verb': "'s", 'object': '[good]', 'TalkID': 7},
#  {'subject': 'that', 'verb': 'doing', 'object': '[good]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'liked', 'object': '[center, pc]', 'TalkID': 7},
#  {'subject': 'i',
#   'verb': 'liked',
#   'object': '[microsoft, spot, watch]',
#   'TalkID': 7},
#  {'subject': "'s", 'verb': 'put', 'object': '[it]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'pay', 'object': '[10]', 'TalkID': 7},
#  {'subject': 'that',
#   'verb': 'has',
#   'object': '[to, be, recharged, every, night, like, your, cell, phone]',
#   'TalkID': 7},
#  {'subject': 'you', 'verb': 'leave', 'object': '[area, code]', 'TalkID': 7},
#  {'subject': 'crunch',
#   'verb': 'going',
#   'object': '[to, get, worse]',
#   'TalkID': 7},
#  {'subject': 'he', 'verb': 'came', 'object': '[this]', 'TalkID': 7},
#  {'subject': 'he', 'verb': 'did', 'object': '[this]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'seen', 'object': '[this]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'seen', 'object': '[evita]', 'TalkID': 7},
#  {'subject': 'i',
#   'verb': 'got',
#   'object': '[to, do, one, about, steve, jobs]',
#   'TalkID': 7},
#  {'subject': 'i',
#   'verb': 'try',
#   'object': "[to, explain, why, i, 'm, back]",
#   'TalkID': 7},
#  {'subject': 'you', 'verb': 'believe', 'object': '[me]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'see', 'object': '[that]', 'TalkID': 7},
#  {'subject': 'you',
#   'verb': 'try',
#   'object': '[rhyming, with, garage]',
#   'TalkID': 7},
#  {'subject': 'i', 'verb': 'left', 'object': '[you]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'know', 'object': '[ropes]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'made', 'object': '[fortune]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'got', 'object': '[drive, vision]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'wear', 'object': '[sandals]', 'TalkID': 7},
#  {'subject': 'laughter', 'verb': 'thank', 'object': '[you]', 'TalkID': 7},
#  {'subject': 'americans', 'verb': 'value', 'object': '[it]', 'TalkID': 7},
#  {'subject': 'mac',
#   'verb': 'had',
#   'object': '[percent, market, share]',
#   'TalkID': 7},
#  {'subject': 'windows',
#   'verb': 'had',
#   'object': '[percent, market, share]',
#   'TalkID': 7},
#  {'subject': 'i', 'verb': 'heard', 'object': '[talk]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'realized', 'object': '[talk]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'know', 'object': '[meaning]', 'TalkID': 7},
#  {'subject': 'ipod', 'verb': 'came', 'object': '[bit]', 'TalkID': 7},
#  {'subject': 'it', 'verb': 'violated', 'object': '[bit]', 'TalkID': 7},
#  {'subject': 'products', 'verb': 'cost', 'object': '[less]', 'TalkID': 7},
#  {'subject': 'products', 'verb': 'had', 'object': '[features]', 'TalkID': 7},
#  {'subject': 'they',
#   'verb': 'had',
#   'object': '[voice, recorders, fm, transmitters]',
#   'TalkID': 7},
#  {'subject': 'products',
#   'verb': 'backed',
#   'object': '[microsoft]',
#   'TalkID': 7},
#  {'subject': 'industry',
#   'verb': 'getting',
#   'object': '[message]',
#   'TalkID': 7},
#  {'subject': 'i', 'verb': 'got', 'object': '[examples]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'have', 'object': '[camera]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'get', 'object': '[pictures]', 'TalkID': 7},
#  {'subject': 'you',
#   'verb': 'haul',
#   'object': '[card, reader, that]',
#   'TalkID': 7},
#  {'subject': 'you', 'verb': 'buy', 'object': '[card, reader]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'haul', 'object': '[that]', 'TalkID': 7},
#  {'subject': 'you', 'verb': 'going', 'object': '[to, lose]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'take', 'object': '[memory, card]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'fold', 'object': '[it]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'stick', 'object': '[it]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'put', 'object': '[it]', 'TalkID': 7},
#  {'subject': 'i',
#   'verb': 'have',
#   'object': '[to, lose, anything]',
#   'TalkID': 7},
#  {'subject': 'you', 'verb': 'seen', 'object': '[this]', 'TalkID': 7},
#  {'subject': 'one', 'verb': 'done', 'object': '[this]', 'TalkID': 7},
#  {'subject': 'it', 'verb': 'pull', 'object': '[laptop]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'do', 'object': '[lot]', 'TalkID': 7},
#  {'subject': 'you',
#   'verb': 'have',
#   'object': '[to, be, kind, of, quiet]',
#   'TalkID': 7},
#  {'subject': 'i', 'verb': 'get', 'object': '[hundreds]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'dictate', 'object': '[what]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'use', 'object': '[feature]', 'TalkID': 7},
#  {'subject': 'it', 'verb': 'getting', 'object': '[echo]', 'TalkID': 7},
#  {'subject': 'it', 'verb': 'write', 'object': '[thing]', 'TalkID': 7},
#  {'subject': 'somebody',
#   'verb': 'sends',
#   'object': '[fan, letter]',
#   'TalkID': 7},
#  {'subject': 'i', 'verb': 'say', 'object': '[thanks]', 'TalkID': 7},
#  {'subject': '[', 'verb': 'thank', 'object': '[you]', 'TalkID': 7},
#  {'subject': 'somebody',
#   'verb': 'sends',
#   'object': '[hate, mail]',
#   'TalkID': 7},
#  {'subject': 'i', 'verb': 'say', 'object': '[piss, off]', 'TalkID': 7},
#  {'subject': 'i', 'verb': 'admire', 'object': '[frankness]', 'TalkID': 7},
#  {'subject': 'they', 'verb': 'put', 'object': '[what]', 'TalkID': 7},
#  {'subject': 'company', 'verb': 'put', 'object': '[features]', 'TalkID': 7},
#  {'subject': 'people', 'verb': 'bought', 'object': '[software]', 'TalkID': 7},
#  {'subject': 'people', 'verb': 'tried', 'object': '[it]', 'TalkID': 7},
#  {'subject': 'they', 'verb': 'put', 'object': '[it]', 'TalkID': 7},
#  {'subject': 'we',
#   'verb': 'going',
#   'object': '[to, do, anything]',
#   'TalkID': 7},
#  {'subject': 'they', 'verb': 'did', 'object': '[what]', 'TalkID': 7},
#  {'subject': 'cult',
#   'verb': 'starting',
#   'object': '[to, spread]',
#   'TalkID': 7},
#  {'subject': 'who', 'verb': 'create', 'object': '[stuff]', 'TalkID': 7},
#  {'subject': '-', 'verb': 'sweat', 'object': '[details]', 'TalkID': 7},
#  {'subject': 'it',
#   'verb': 'deciding',
#   'object': '[what, to, leave, out]',
#   'TalkID': 7},
#  {'subject': 'i', 'verb': 'blown', 'object': '[thing]', 'TalkID': 66},
#  {'subject': 'i',
#   'verb': 'want',
#   'object': '[what, to, talk, about]',
#   'TalkID': 66},
#  {'subject': 'we', 'verb': 'had', 'object': '[that]', 'TalkID': 66},
#  {'subject': 'it', 'verb': 'put', 'object': '[us]', 'TalkID': 66},
#  {'subject': 'we', 'verb': 'have', 'object': '[idea]', 'TalkID': 66},
#  {'subject': 'what', 'verb': 'going', 'object': '[to, happen]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'have', 'object': '[interest]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'find', 'object': '[what]', 'TalkID': 66},
#  {'subject': 'everybody', 'verb': 'has', 'object': '[interest]', 'TalkID': 66},
#  {'subject': 'you', 'verb': 'do', 'object': '[what]', 'TalkID': 66},
#  {'subject': 'they', 'verb': 'pin', 'object': '[you]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'have', 'object': '[interest]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'think', 'object': '[interest]', 'TalkID': 66},
#  {'subject': 'we', 'verb': 'have', 'object': '[interest]', 'TalkID': 66},
#  {'subject': 'that',
#   'verb': 'meant',
#   'object': "[to, take, us, into, this, future, that, we, ca, n't, grasp]",
#   'TalkID': 66},
#  {'subject': 'nobody', 'verb': 'has', 'object': '[clue]', 'TalkID': 66},
#  {'subject': 'we',
#   'verb': 'meant',
#   'object': '[to, be, educating, them, for, it]',
#   'TalkID': 66},
#  {'subject': 'children', 'verb': 'have', 'object': '[that]', 'TalkID': 66},
#  {'subject': 'she', 'verb': 'do', 'object': '[what]', 'TalkID': 66},
#  {'subject': 'who', 'verb': 'found', 'object': '[talent]', 'TalkID': 66},
#  {'subject': 'kids', 'verb': 'have', 'object': '[talents]', 'TalkID': 66},
#  {'subject': 'we', 'verb': 'squander', 'object': '[them]', 'TalkID': 66},
#  {'subject': 'i',
#   'verb': 'want',
#   'object': '[to, talk, about, education]',
#   'TalkID': 66},
#  {'subject': 'i',
#   'verb': 'want',
#   'object': '[to, talk, about, creativity]',
#   'TalkID': 66},
#  {'subject': 'we', 'verb': 'treat', 'object': '[it]', 'TalkID': 66},
#  {'subject': 'applause', 'verb': 'thank', 'object': '[you]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'heard', 'object': '[story]', 'TalkID': 66},
#  {'subject': 'i',
#   'verb': 'love',
#   'object': '[telling, it, —, of, a, little, girl, who, was, in, a, drawing, lesson]',
#   'TalkID': 66},
#  {'subject': 'girl', 'verb': 'paid', 'object': '[attention]', 'TalkID': 66},
#  {'subject': 'she', 'verb': 'did', 'object': '[attention]', 'TalkID': 66},
#  {'subject': 'you', 'verb': 'drawing', 'object': '[what]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'drawing', 'object': '[picture]', 'TalkID': 66},
#  {'subject': 'you', 'verb': 'remember', 'object': '[story]', 'TalkID': 66},
#  {'subject': 'gibson', 'verb': 'did', 'object': '[sequel]', 'TalkID': 66},
#  {'subject': 'you', 'verb': 'seen', 'object': '[it]', 'TalkID': 66},
#  {'subject': 'james', 'verb': 'got', 'object': '[part]', 'TalkID': 66},
#  {'subject': 'he', 'verb': 'have', 'object': '[to, speak]', 'TalkID': 66},
#  {'subject': 'you', 'verb': 'know', 'object': '[bit]', 'TalkID': 66},
#  {'subject': 'boys', 'verb': 'came', 'object': '[boxes]', 'TalkID': 66},
#  {'subject': 'they', 'verb': 'put', 'object': '[boxes]', 'TalkID': 66},
#  {'subject': 'boy', 'verb': 'said', 'object': '[boxes]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'bring', 'object': '[gold]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'bring', 'object': '[myrrh]', 'TalkID': 66},
#  {'subject': 'frank', 'verb': 'sent', 'object': '[this]', 'TalkID': 66},
#  {'subject': 'kids', 'verb': 'take', 'object': '[chance]', 'TalkID': 66},
#  {'subject': 'they', 'verb': 'have', 'object': '[go]', 'TalkID': 66},
#  {'subject': 'i',
#   'verb': 'mean',
#   'object': '[to, say, that, being, wrong, is, the, same, thing, as, being, creative]',
#   'TalkID': 66},
#  {'subject': 'we', 'verb': 'know', 'object': '[what]', 'TalkID': 66},
#  {'subject': 'they',
#   'verb': 'get',
#   'object': '[to, be, adults]',
#   'TalkID': 66},
#  {'subject': 'kids', 'verb': 'lost', 'object': '[capacity]', 'TalkID': 66},
#  {'subject': 'we', 'verb': 'run', 'object': '[companies]', 'TalkID': 66},
#  {'subject': 'we', 'verb': 'stigmatize', 'object': '[mistakes]', 'TalkID': 66},
#  {'subject': 'we',
#   'verb': 'running',
#   'object': '[education, systems]',
#   'TalkID': 66},
#  {'subject': 'we', 'verb': 'educating', 'object': '[people]', 'TalkID': 66},
#  {'subject': 'picasso', 'verb': 'said', 'object': '[this]', 'TalkID': 66},
#  {'subject': 'he', 'verb': 'said', 'object': '[artists]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'believe', 'object': '[this]', 'TalkID': 66},
#  {'subject': 'you', 'verb': 'imagine', 'object': '[transition]', 'TalkID': 66},
#  {'subject': 'you', 'verb': 'struck', 'object': '[thought]', 'TalkID': 66},
#  {'subject': 'we',
#   'verb': 'moved',
#   'object': '[to, say, a, word, about, the, transition]',
#   'TalkID': 66},
#  {'subject': 'i',
#   'verb': 'want',
#   'object': '[to, say, a, word, about, the, transition]',
#   'TalkID': 66},
#  {'subject': 'son', 'verb': 'want', 'object': '[to, come]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'got', 'object': '[kids]', 'TalkID': 66},
#  {'subject': 'he',
#   'verb': 'want',
#   'object': '[to, come, to, los, angeles]',
#   'TalkID': 66},
#  {'subject': 'he', 'verb': 'loved', 'object': '[it]', 'TalkID': 66},
#  {'subject': 'he', 'verb': 'had', 'object': '[girlfriend]', 'TalkID': 66},
#  {'subject': 'he', 'verb': 'known', 'object': '[her]', 'TalkID': 66},
#  {'subject': 'laughter', 'verb': 'mind', 'object': '[you]', 'TalkID': 66},
#  {'subject': 'they', 'verb': 'had', 'object': '[anniversary]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'find', 'object': '[girl]', 'TalkID': 66},
#  {'subject': 'we', 'verb': 'leaving', 'object': '[country]', 'TalkID': 66},
#  {'subject': 'something', 'verb': 'strikes', 'object': '[you]', 'TalkID': 66},
#  {'subject': 'system', 'verb': 'has', 'object': '[hierarchy]', 'TalkID': 66},
#  {'subject': 'music', 'verb': 'given', 'object': '[status]', 'TalkID': 66},
#  {'subject': 'that', 'verb': 'teaches', 'object': '[dance]', 'TalkID': 66},
#  {'subject': 'we', 'verb': 'teach', 'object': '[mathematics]', 'TalkID': 66},
#  {'subject': 'they', 'verb': 'allowed', 'object': '[to]', 'TalkID': 66},
#  {'subject': 'we', 'verb': 'have', 'object': '[bodies]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'miss', 'object': '[meeting]', 'TalkID': 66},
#  {'subject': 'we',
#   'verb': 'start',
#   'object': '[to, educate, them, progressively, from, the, waist, up]',
#   'TalkID': 66},
#  {'subject': 'you', 'verb': 'have', 'object': '[to, conclude]', 'TalkID': 66},
#  {'subject': 'who', 'verb': 'does', 'object': '[everything]', 'TalkID': 66},
#  {'subject': 'who',
#   'verb': 'gets',
#   'object': '[that, brownie, points]',
#   'TalkID': 66},
#  {'subject': 'you',
#   'verb': 'have',
#   'object': '[to, conclude, the, whole, purpose, of, public, education, throughout, the, world]',
#   'TalkID': 66},
#  {'subject': 'who', 'verb': 'come', 'object': '[top]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'used', 'object': '[to, be, one]', 'TalkID': 66},
#  {'subject': 'i',
#   'verb': 'like',
#   'object': '[university, professors]',
#   'TalkID': 66},
#  {'subject': 'we', 'verb': 'hold', 'object': '[them]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'say', 'object': '[this]', 'TalkID': 66},
#  {'subject': 'laughter', 'verb': 'get', 'object': '[yourself]', 'TalkID': 66},
#  {'subject': 'you', 'verb': 'want', 'object': '[evidence]', 'TalkID': 66},
#  {'subject': 'you', 'verb': 'see', 'object': '[it]', 'TalkID': 66},
#  {'subject': 'they', 'verb': 'go', 'object': '[paper]', 'TalkID': 66},
#  {'subject': 'they', 'verb': 'write', 'object': '[paper]', 'TalkID': 66},
#  {'subject': 'you', 'verb': 'get', 'object': '[job]', 'TalkID': 66},
#  {'subject': 'you',
#   'verb': 'going',
#   'object': '[to, be, a, musician]',
#   'TalkID': 66},
#  {'subject': 'universities',
#   'verb': 'designed',
#   'object': '[system]',
#   'TalkID': 66},
#  {'subject': 'we',
#   'verb': 'afford',
#   'object': '[to, go, on, that, way]',
#   'TalkID': 66},
#  {'subject': 'you', 'verb': 'had', 'object': '[degree]', 'TalkID': 66},
#  {'subject': 'you', 'verb': 'had', 'object': '[job]', 'TalkID': 66},
#  {'subject': 'you', 'verb': 'have', 'object': '[job]', 'TalkID': 66},
#  {'subject': 'you', 'verb': 'want', 'object': '[one]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'want', 'object': '[one]', 'TalkID': 66},
#  {'subject': 'kids', 'verb': 'heading', 'object': '[phd]', 'TalkID': 66},
#  {'subject': 'you', 'verb': 'need', 'object': '[ma]', 'TalkID': 66},
#  {'subject': 'job', 'verb': 'required', 'object': '[ba]', 'TalkID': 66},
#  {'subject': 'you', 'verb': 'need', 'object': '[phd]', 'TalkID': 66},
#  {'subject': 'we',
#   'verb': 'need',
#   'object': '[to, radically, rethink, our, view, of, intelligence]',
#   'TalkID': 66},
#  {'subject': 'we', 'verb': 'know', 'object': '[things]', 'TalkID': 66},
#  {'subject': 'we', 'verb': 'experience', 'object': '[it]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'define', 'object': '[which]', 'TalkID': 66},
#  {'subject': 'that', 'verb': 'have', 'object': '[value]', 'TalkID': 66},
#  {'subject': 'that', 'verb': 'joins', 'object': '[halves]', 'TalkID': 66},
#  {'subject': 'i', 'verb': "'s", 'object': '[it]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'know', 'object': '[it]', 'TalkID': 66},
#  {'subject': 'wife', 'verb': 'cooking', 'object': '[meal]', 'TalkID': 66},
#  {'subject': 'she', 'verb': 'painting', 'object': '[ceiling]', 'TalkID': 66},
#  {'subject': 'she',
#   'verb': 'doing',
#   'object': '[heart, surgery]',
#   'TalkID': 66},
#  {'subject': 'i',
#   'verb': 'trying',
#   'object': '[to, fry, an, egg, in, here]',
#   'TalkID': 66},
#  {'subject': 'laughter', 'verb': 'give', 'object': '[break]', 'TalkID': 66},
#  {'subject': 'you', 'verb': 'know', 'object': '[thing]', 'TalkID': 66},
#  {'subject': 'tree', 'verb': 'falls', 'object': '[it]', 'TalkID': 66},
#  {'subject': 'nobody', 'verb': 'hears', 'object': '[it]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'saw', 'object': '[t, shirt]', 'TalkID': 66},
#  {'subject': 'man', 'verb': 'speaks', 'object': '[mind]', 'TalkID': 66},
#  {'subject': 'woman', 'verb': 'hears', 'object': '[him]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'doing', 'object': '[book]', 'TalkID': 66},
#  {'subject': 'they', 'verb': 'discovered', 'object': '[talent]', 'TalkID': 66},
#  {'subject': 'people',
#   'verb': 'got',
#   'object': '[to, be, there]',
#   'TalkID': 66},
#  {'subject': 'it',
#   'verb': 'prompted',
#   'object': '[conversation]',
#   'TalkID': 66},
#  {'subject': 'everybody', 'verb': 'knows', 'object': '[work]', 'TalkID': 66},
#  {'subject': 'i',
#   'verb': 'used',
#   'object': '[to, be, on, the, board, of, the, royal, ballet, ,]',
#   'TalkID': 66},
#  {'subject': 'i', 'verb': 'had', 'object': '[lunch]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'said', 'object': '[lunch]', 'TalkID': 66},
#  {'subject': 'you',
#   'verb': 'get',
#   'object': '[to, be, a, dancer]',
#   'TalkID': 66},
#  {'subject': 'gillian',
#   'verb': 'has',
#   'object': '[learning, disorder]',
#   'TalkID': 66},
#  {'subject': 'she', 'verb': 'had', 'object': '[adhd]', 'TalkID': 66},
#  {'subject': 'they', 'verb': 'have', 'object': '[that]', 'TalkID': 66},
#  {'subject': 'she', 'verb': 'disturbing', 'object': '[people]', 'TalkID': 66},
#  {'subject': 'mother', 'verb': 'told', 'object': '[me]', 'TalkID': 66},
#  {'subject': 'i',
#   'verb': 'need',
#   'object': '[to, speak, to, her, privately]',
#   'TalkID': 66},
#  {'subject': 'they', 'verb': 'went', 'object': '[her]', 'TalkID': 66},
#  {'subject': 'they', 'verb': 'left', 'object': '[her]', 'TalkID': 66},
#  {'subject': 'he', 'verb': 'turned', 'object': '[radio]', 'TalkID': 66},
#  {'subject': 'he',
#   'verb': 'said',
#   'object': '[just, stand, and, watch, her]',
#   'TalkID': 66},
#  {'subject': 'they', 'verb': 'left', 'object': '[room]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'tell', 'object': '[you]', 'TalkID': 66},
#  {'subject': 'who',
#   'verb': 'had',
#   'object': '[to, move, to, think]',
#   'TalkID': 66},
#  {'subject': 'who',
#   'verb': 'had',
#   'object': '[to, move, to, think]',
#   'TalkID': 66},
#  {'subject': 'they',
#   'verb': 'ballet',
#   'object': '[contemporary]',
#   'TalkID': 66},
#  {'subject': 'they', 'verb': 'did', 'object': '[tap]', 'TalkID': 66},
#  {'subject': 'they', 'verb': 'did', 'object': '[contemporary]', 'TalkID': 66},
#  {'subject': 'she', 'verb': 'had', 'object': '[career]', 'TalkID': 66},
#  {'subject': 'she',
#   'verb': 'graduated',
#   'object': '[gillian, dance, company, andrew, lloyd, webber]',
#   'TalkID': 66},
#  {'subject': 'she',
#   'verb': 'founded',
#   'object': '[gillian, dance, company]',
#   'TalkID': 66},
#  {'subject': 'she',
#   'verb': 'met',
#   'object': '[andrew, lloyd, webber]',
#   'TalkID': 66},
#  {'subject': 'she', 'verb': 'given', 'object': '[pleasure]', 'TalkID': 66},
#  {'subject': 'somebody', 'verb': 'put', 'object': '[her]', 'TalkID': 66},
#  {'subject': 'somebody', 'verb': 'told', 'object': '[her]', 'TalkID': 66},
#  {'subject': 'it', 'verb': 'comes', 'object': '[what]', 'TalkID': 66},
#  {'subject': 'gore', 'verb': 'spoke', 'object': '[night]', 'TalkID': 66},
#  {'subject': 'that',
#   'verb': 'triggered',
#   'object': '[rachel, carson]',
#   'TalkID': 66},
#  {'subject': 'we',
#   'verb': 'start',
#   'object': '[to, reconstitute, our, conception, of, the, richness, of, human, capacity]',
#   'TalkID': 66},
#  {'subject': 'system', 'verb': 'mined', 'object': '[minds]', 'TalkID': 66},
#  {'subject': 'strip', 'verb': 'mine', 'object': '[earth]', 'TalkID': 66},
#  {'subject': 'it', 'verb': 'serve', 'object': '[us]', 'TalkID': 66},
#  {'subject': 'we',
#   'verb': 'have',
#   'object': "[to, rethink, the, fundamental, principles, on, which, we, 're, educating, our, children]",
#   'TalkID': 66},
#  {'subject': 'we', 'verb': 'educating', 'object': '[children]', 'TalkID': 66},
#  {'subject': 'we',
#   'verb': 'have',
#   'object': "[to, be, careful, now, that, we, use, this, gift, wisely, and, that, we, avert, some, of, the, scenarios, that, we, 've, talked, about]",
#   'TalkID': 66},
#  {'subject': 'we', 'verb': 'use', 'object': '[gift]', 'TalkID': 66},
#  {'subject': 'we', 'verb': 'avert', 'object': '[some]', 'TalkID': 66},
#  {'subject': 'we', 'verb': 'do', 'object': '[it]', 'TalkID': 66},
#  {'subject': 'they', 'verb': 'face', 'object': '[future]', 'TalkID': 66},
#  {'subject': 'we', 'verb': 'see', 'object': '[future]', 'TalkID': 66},
#  {'subject': 'them', 'verb': 'make', 'object': '[something]', 'TalkID': 66},
#  {'subject': 'i', 'verb': 'took', 'object': '[task]', 'TalkID': 92},
#  {'subject': 'you', 'verb': 'get', 'object': '[opportunity]', 'TalkID': 92},
#  {'subject': 'students', 'verb': 'have', 'object': '[grade]', 'TalkID': 92},
#  {'subject': 'they', 'verb': 'know', 'object': '[everything]', 'TalkID': 92},
#  {'subject': 'i',
#   'verb': 'going',
#   'object': '[to, teach, them, about]',
#   'TalkID': 92},
#  {'subject': 'i', 'verb': 'did', 'object': '[pre, -, test]', 'TalkID': 92},
#  {'subject': 'i', 'verb': 'learned', 'object': '[lot]', 'TalkID': 92},
#  {'subject': 'country',
#   'verb': 'has',
#   'object': '[child, mortality]',
#   'TalkID': 92},
#  {'subject': 'i', 'verb': 'put', 'object': '[them]', 'TalkID': 92},
#  {'subject': 'one',
#   'verb': 'has',
#   'object': '[child, mortality]',
#   'TalkID': 92},
#  {'subject': 'i', 'verb': 'put', 'object': '[you]', 'TalkID': 92},
#  {'subject': 'i', 'verb': 'did', 'object': '[it]', 'TalkID': 92},
#  {'subject': 'i',
#   'verb': 'got',
#   'object': '[confidence, interval]',
#   'TalkID': 92},
#  {'subject': 'i', 'verb': 'got', 'object': '[right, answer]', 'TalkID': 92},
#  {'subject': 'i', 'verb': 'realized', 'object': '[discovery]', 'TalkID': 92},
#  {'subject': 'i', 'verb': 'compiling', 'object': '[report]', 'TalkID': 92},
#  {'subject': 'i', 'verb': 'gave', 'object': '[bananas]', 'TalkID': 92},
#  {'subject': 'i', 'verb': 'did', 'object': '[study]', 'TalkID': 92},
#  {'subject': 'that',
#   'verb': 'hands',
#   'object': '[nobel, prize]',
#   'TalkID': 92},
#  {'subject': 'we', 'verb': 'did', 'object': '[software]', 'TalkID': 92},
#  {'subject': 'which', 'verb': 'displays', 'object': '[it]', 'TalkID': 92},
#  {'subject': 'i', 'verb': 'put', 'object': '[fertility, rate]', 'TalkID': 92},
#  {'subject': 'they', 'verb': 'said', 'object': '[what]', 'TalkID': 92},
#  {'subject': 'i', 'verb': 'asked', 'object': '[them]', 'TalkID': 92},
#  {'subject': 'you', 'verb': 'think', 'object': '[what]', 'TalkID': 92},
#  {'subject': 'you', 'verb': 'mean', 'object': '[what]', 'TalkID': 92},
#  {'subject': 'i', 'verb': 'display', 'object': '[what]', 'TalkID': 92},
#  {'subject': 'i',
#   'verb': 'put',
#   'object': '[fertility, rate, number]',
#   'TalkID': 92},
#  {'subject': 'we', 'verb': 'have', 'object': '[data]', 'TalkID': 92},
#  {'subject': 'i', 'verb': 'put', 'object': '[life, expectancy]', 'TalkID': 92},
#  {'subject': 'they',
#   'verb': 'was',
#   'object': '[families, lives]',
#   'TalkID': 92},
#  {'subject': 'they',
#   'verb': 'had',
#   'object': '[families, lives]',
#   'TalkID': 92},
#  {'subject': 'they', 'verb': 'had', 'object': '[families]', 'TalkID': 92},
#  {'subject': 'they', 'verb': 'had', 'object': '[lives]', 'TalkID': 92},
#  {'subject': 'we',
#   'verb': 'want',
#   'object': '[to, see, the, change]',
#   'TalkID': 92},
#  {'subject': 'countries', 'verb': 'got', 'object': '[families]', 'TalkID': 92},
#  {'subject': 'they', 'verb': 'live', 'object': '[families]', 'TalkID': 92},
#  {'subject': 'they', 'verb': 'got', 'object': '[lives]', 'TalkID': 92},
#  {'subject': 'we', 'verb': 'stopped', 'object': '[world]', 'TalkID': 92},
#  {'subject': 'they',
#   'verb': 'get',
#   'object': '[life, families]',
#   'TalkID': 92},
#  {'subject': 'you', 'verb': 'have', 'object': '[bangladesh]', 'TalkID': 92},
#  {'subject': 'imams',
#   'verb': 'start',
#   'object': '[to, promote, family, planning]',
#   'TalkID': 92},
#  {'subject': 'epidemic', 'verb': 'move', 'object': '[world]', 'TalkID': 92},
#  {'subject': 'that',
#   'verb': 'takes',
#   'object': '[life, expectancy, rest]',
#   'TalkID': 92},
#  {'subject': 'we', 'verb': 'have', 'object': '[lives, family]', 'TalkID': 92},
#  {'subject': 'we', 'verb': 'have', 'object': '[world]', 'TalkID': 92},
#  {'subject': 'me', 'verb': 'make', 'object': '[comparison]', 'TalkID': 92},
#  {'subject': 'america',
#   'verb': 'had',
#   'object': '[families, life]',
#   'TalkID': 92},
#  {'subject': 'vietnam',
#   'verb': 'had',
#   'object': '[families, lives]',
#   'TalkID': 92},
#  {'subject': 'they', 'verb': 'give', 'object': '[planning]', 'TalkID': 92},
#  {'subject': 'they', 'verb': 'go', 'object': '[planning]', 'TalkID': 92},
#  {'subject': 'it', 'verb': 'moves', 'object': '[planning]', 'TalkID': 92},
#  {'subject': 'we',
#   'verb': 'have',
#   'object': '[life, expectancy, family, size]',
#   'TalkID': 92},
#  {'subject': 'we',
#   'verb': 'underestimate',
#   'object': '[change]',
#   'TalkID': 92},
#  {'subject': 'we', 'verb': 'saw', 'object': '[change]', 'TalkID': 92},
#  {'subject': 'we',
#   'verb': 'display',
#   'object': '[distribution]',
#   'TalkID': 92},
# ...
#  {'subject': 'we', 'verb': 'have', 'object': '[resources]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'take', 'object': '[look]', 'TalkID': 96},
#  {'subject': 'they', 'verb': 'accomplished', 'object': '[that]', 'TalkID': 96},
#  {'subject': 'he', 'verb': 'broken', 'object': '[pattern]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'appreciated', 'object': '[energy]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'tell', 'object': '[that]', 'TalkID': 96},
#  {'subject': 'what',
#   'verb': 'determines',
#   'object': '[resources]',
#   'TalkID': 96},
#  {'subject': 'decisions',
#   'verb': 'shape',
#   'object': '[destiny]',
#   'TalkID': 96},
#  {'subject': 'decisions',
#   'verb': 'shape',
#   'object': '[destiny]',
#   'TalkID': 96},
#  {'subject': 'you',
#   'verb': 'have',
#   'object': "[to, decide, what, you, 're, going, to, focus, on]",
#   'TalkID': 96},
#  {'subject': 'you',
#   'verb': 'going',
#   'object': '[what, to, focus, on]',
#   'TalkID': 96},
#  {'subject': 'you', 'verb': 'decide', 'object': '[to, focus]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'give', 'object': '[meaning]', 'TalkID': 96},
#  {'subject': 'meaning',
#   'verb': 'produces',
#   'object': '[emotion]',
#   'TalkID': 96},
#  {'subject': 'god', 'verb': 'punishing', 'object': '[me]', 'TalkID': 96},
#  {'subject': 'god', 'verb': 'rewarding', 'object': '[me]', 'TalkID': 96},
#  {'subject': 'we', 'verb': 'going', 'object': '[what, to, do]', 'TalkID': 96},
#  {'subject': 'that', 'verb': 'shaped', 'object': '[destiny]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'made', 'object': '[decision]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'met', 'object': '[love]', 'TalkID': 96},
#  {'subject': 'i',
#   'verb': 'know',
#   'object': '[google, geniuses]',
#   'TalkID': 96},
#  {'subject': 'they', 'verb': 'made', 'object': '[decision]', 'TalkID': 96},
#  {'subject': 'she', 'verb': 'affect', 'object': '[life]', 'TalkID': 96},
#  {'subject': 'decision',
#   'verb': 'shaped',
#   'object': '[culture]',
#   'TalkID': 96},
#  {'subject': 'you', 'verb': 'got', 'object': '[cancer]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'ride', 'object': '[bike]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'got', 'object': '[it]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'got', 'object': '[it]', 'TalkID': 96},
#  {'subject': 'it', 'verb': 'mean', 'object': '[what]', 'TalkID': 96},
#  {'subject': 'he', 'verb': 'goes', 'object': '[championships]', 'TalkID': 96},
#  {'subject': 'he', 'verb': 'wins', 'object': '[championships]', 'TalkID': 96},
#  {'subject': 'he', 'verb': 'got', 'object': '[strength]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'seen', 'object': '[that]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'had', 'object': '[people]', 'TalkID': 96},
#  {'subject': 'what', 'verb': 'shaped', 'object': '[lance]', 'TalkID': 96},
#  {'subject': 'what', 'verb': 'shapes', 'object': '[you]', 'TalkID': 96},
#  {'subject': 'we', 'verb': 'had', 'object': '[times]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'did', 'object': '[something]', 'TalkID': 96},
#  {'subject': 'i',
#   'verb': 'believe',
#   'object': '[something, that]',
#   'TalkID': 96},
#  {'subject': 'you', 'verb': 'did', 'object': '[that]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'did', 'object': '[something]', 'TalkID': 96},
#  {'subject': 'what', 'verb': 'shapes', 'object': '[term]', 'TalkID': 96},
#  {'subject': 'what', 'verb': 'shaping', 'object': '[us]', 'TalkID': 96},
#  {'subject': 'people', 'verb': 'make', 'object': '[decisions]', 'TalkID': 96},
#  {'subject': 'we',
#   'verb': 'need',
#   'object': '[to, know, what, already, influences, them]',
#   'TalkID': 96},
#  {'subject': 'what', 'verb': 'influences', 'object': '[them]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'get', 'object': '[desires, goals]', 'TalkID': 96},
#  {'subject': 'who',
#   'verb': 'got',
#   'object': '[goal, desire, thought]',
#   'TalkID': 96},
#  {'subject': 'you', 'verb': 'uncover', 'object': '[it]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'form', 'object': '[it]', 'TalkID': 96},
#  {'subject': 'that', 'verb': 'tell', 'object': '[you]', 'TalkID': 96},
#  {'subject': 'me', 'verb': 'tell', 'object': '[you]', 'TalkID': 96},
#  {'subject': 'everyone',
#   'verb': 'needs',
#   'object': '[certainty]',
#   'TalkID': 96},
#  {'subject': 'they', 'verb': 'avoid', 'object': '[pain]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'get', 'object': '[it]', 'TalkID': 96},
#  {'subject': 'we', 'verb': 'need', 'object': '[that]', 'TalkID': 96},
#  {'subject': 'we', 'verb': 'get', 'object': '[certainty]', 'TalkID': 96},
#  {'subject': 'we', 'verb': 'get', 'object': '[what]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'feel', 'object': '[what]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'feel', 'object': '[what]', 'TalkID': 96},
#  {'subject': 'god', 'verb': 'gave', 'object': '[need]', 'TalkID': 96},
#  {'subject': 'we', 'verb': 'need', 'object': '[variety]', 'TalkID': 96},
#  {'subject': 'we', 'verb': 'need', 'object': '[surprise]', 'TalkID': 96},
#  {'subject': 'many', 'verb': 'love', 'object': '[surprises]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'like', 'object': '[surprises]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'call', 'object': '[problems]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'need', 'object': '[them]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'rented', 'object': '[video, film]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'seen', 'object': '[that]', 'TalkID': 96},
#  {'subject': 'who', 'verb': 'done', 'object': '[this]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'doing', 'object': '[it]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'read', 'object': '[it]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'saw', 'object': '[it]', 'TalkID': 96},
#  {'subject': 'we',
#   'verb': 'need',
#   'object': '[to, feel, important, ,, special, ,, unique]',
#   'TalkID': 96},
#  {'subject': 'you', 'verb': 'get', 'object': '[it]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'do', 'object': '[it]', 'TalkID': 96},
#  {'subject': 'you',
#   'verb': 'put',
#   'object': '[tattoos, earrings]',
#   'TalkID': 96},
#  {'subject': 'you', 'verb': 'want', 'object': '[to, know]', 'TalkID': 96},
#  {'subject': 'it', 'verb': 'takes', 'object': '[whatever]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'have', 'object': '[background]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'put', 'object': '[gun]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'live', 'object': '[gun]', 'TalkID': 96},
#  {'subject': 'you',
#   'verb': 'going',
#   'object': '[to, respond, to, me]',
#   'TalkID': 96},
#  {'subject': 'what',
#   'verb': 'going',
#   'object': '[to, happen, next]',
#   'TalkID': 96},
#  {'subject': 'you',
#   'verb': 'want',
#   'object': '[to, risk, your, life, for, it]',
#   'TalkID': 96},
#  {'subject': 'we',
#   'verb': 'have',
#   'object': '[consciousness, change]',
#   'TalkID': 96},
#  {'subject': 'you', 'verb': 'get', 'object': '[significance]', 'TalkID': 96},
#  {'subject': 'you',
#   'verb': 'got',
#   'object': '[to, be, unique, and, different]',
#   'TalkID': 96},
#  {'subject': 'we', 'verb': 'need', 'object': '[what]', 'TalkID': 96},
#  {'subject': 'we', 'verb': 'want', 'object': '[it]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'raise', 'object': '[hand]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'had', 'object': '[shit]', 'TalkID': 96},
#  {'subject': 'you',
#   'verb': 'going',
#   'object': '[to, get, hurt, again]',
#   'TalkID': 96},
#  {'subject': 'we', 'verb': 'need', 'object': '[it]', 'TalkID': 96},
#  {'subject': 'we', 'verb': 'do', 'object': '[it]', 'TalkID': 96},
#  {'subject': 'human', 'verb': 'finds', 'object': '[way]', 'TalkID': 96},
#  {'subject': 'you',
#   'verb': 'need',
#   'object': '[to, have, split, personalities]',
#   'TalkID': 96},
#  {'subject': 'you', 'verb': 'get', 'object': '[it]', 'TalkID': 96},
#  {'subject': 'you',
#   'verb': 'figure',
#   'object': '[way, smoke, drink]',
#   'TalkID': 96},
#  {'subject': 'whatever', 'verb': 'meet', 'object': '[four]', 'TalkID': 96},
#  {'subject': 'we', 'verb': 'know', 'object': '[answer]', 'TalkID': 96},
#  {'subject': 'you',
#   'verb': 'have',
#   'object': '[money, friends]',
#   'TalkID': 96},
#  {'subject': 'many', 'verb': 'love', 'object': '[you]', 'TalkID': 96},
#  {'subject': 'we', 'verb': 'have', 'object': '[something]', 'TalkID': 96},
#  {'subject': 'room', 'verb': 'knows', 'object': '[that]', 'TalkID': 96},
#  {'subject': 'he', 'verb': 'got', 'object': '[calling]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'feel', 'object': '[difference]', 'TalkID': 96},
#  {'subject': 'calling', 'verb': 'touch', 'object': '[people]', 'TalkID': 96},
#  {'subject': 'we', 'verb': 'going', 'object': '[to, starve]', 'TalkID': 96},
#  {'subject': 'mom', 'verb': 'letting', 'object': '[food]', 'TalkID': 96},
#  {'subject': 'somebody', 'verb': 'came', 'object': '[food]', 'TalkID': 96},
#  {'subject': 'mom', 'verb': 'delivered', 'object': '[food]', 'TalkID': 96},
#  {'subject': 'father', 'verb': 'made', 'object': '[decisions]', 'TalkID': 96},
#  {'subject': 'it', 'verb': 'mean', 'object': '[what]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'have', 'object': '[what, to, do]', 'TalkID': 96},
#  {'subject': 'he', 'verb': 'did', 'object': '[which]', 'TalkID': 96},
#  {'subject': 'decisions', 'verb': 'gave', 'object': '[path]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'set', 'object': '[focus]', 'TalkID': 96},
#  {'subject': 'what', 'verb': 'changed', 'object': '[life]', 'TalkID': 96},
#  {'subject': 'one', 'verb': 'gives', 'object': '[shit]', 'TalkID': 96},
#  {'subject': 'me', 'verb': 'believe', 'object': '[this]', 'TalkID': 96},
#  {'subject': 'i',
#   'verb': 'going',
#   'object': '[to, do, something, to, make, a, difference]',
#   'TalkID': 96},
#  {'subject': 'i', 'verb': 'did', 'object': '[four]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'tell', 'object': '[anybody]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'doing', 'object': '[what]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'doing', 'object': '[it]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'use', 'object': '[help]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'grew', 'object': '[companies]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'got', 'object': '[11]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'built', 'object': '[foundation]', 'TalkID': 96},
#  {'subject': 'we', 'verb': 'fed', 'object': '[people]', 'TalkID': 96},
#  {'subject': 'applause', 'verb': 'thank', 'object': '[you]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'tell', 'object': '[you, that]', 'TalkID': 96},
#  {'subject': 'they', 'verb': 'had', 'object': '[chance]', 'TalkID': 96},
#  {'subject': 'that', 'verb': 'shapes', 'object': '[you]', 'TalkID': 96},
#  {'subject': 'we', 'verb': 'have', 'object': '[needs]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'value', 'object': '[what]', 'TalkID': 96},
#  {'subject': 'you',
#   'verb': 'driven',
#   'object': '[significance, love]',
#   'TalkID': 96},
#  {'subject': 'we', 'verb': 'need', 'object': '[six]', 'TalkID': 96},
#  {'subject': 'is', 'verb': 'tilts', 'object': '[you]', 'TalkID': 96},
#  {'subject': 'you',
#   'verb': 'have',
#   'object': '[destination, destiny]',
#   'TalkID': 96},
#  {'subject': 'system', 'verb': 'tells', 'object': '[you]', 'TalkID': 96},
#  {'subject': 'i',
#   'verb': 'going',
#   'object': '[to, save, lives, even, if, i, die, for, other, people]',
#   'TalkID': 96},
#  {'subject': 'somebody', 'verb': 'says', 'object': '[you]', 'TalkID': 96},
#  {'subject': 'i',
#   'verb': 'going',
#   'object': '[to, kill, people, to, do, it]',
#   'TalkID': 96},
#  {'subject': 'they',
#   'verb': 'trying',
#   'object': '[to, meet, the, same, needs, of, significance]',
#   'TalkID': 96},
#  {'subject': 'they',
#   'verb': 'want',
#   'object': '[to, honor, god, or, honor, their, family]',
#   'TalkID': 96},
#  {'subject': 'they', 'verb': 'have', 'object': '[map]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'have', 'object': '[what]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'got', 'object': '[target, map]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'use', 'object': '[google]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'love', 'object': '[macs]', 'TalkID': 96},
#  {'subject': 'they', 'verb': 'made', 'object': '[google]', 'TalkID': 96},
#  {'subject': 'many', 'verb': 'made', 'object': '[mistake]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'use', 'object': '[thing]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'get', 'object': '[thing]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'want', 'object': '[where, to, go]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'tell', 'object': '[you]', 'TalkID': 96},
#  {'subject': 'we', 'verb': 'have', 'object': '[words]', 'TalkID': 96},
#  {'subject': 'they',
#   'verb': 'write',
#   'object': '[emotions, disempowering]',
#   'TalkID': 96},
#  {'subject': 'i', 'verb': 'have', 'object': '[people, 1,000]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'have', 'object': '[people, 1,000]', 'TalkID': 96},
#  {'subject': 'them', 'verb': 'write', 'object': '[emotions]', 'TalkID': 96},
#  {'subject': 'they', 'verb': 'experience', 'object': '[that]', 'TalkID': 96},
#  {'subject': 'they',
#   'verb': 'experience',
#   'object': '[emotions]',
#   'TalkID': 96},
#  {'subject': 'they', 'verb': 'have', 'object': '[feelings]', 'TalkID': 96},
#  {'subject': 'many', 'verb': 'know', 'object': '[somebody]', 'TalkID': 96},
#  {'subject': 'who', 'verb': 'finds', 'object': '[way]', 'TalkID': 96},
#  {'subject': 'they', 'verb': 'find', 'object': '[way]', 'TalkID': 96},
#  {'subject': 'many', 'verb': 'know', 'object': '[somebody]', 'TalkID': 96},
#  {'subject': 'we',
#   'verb': 'translating',
#   'object': '[languages]',
#   'TalkID': 96},
#  {'subject': 'i', 'verb': 'got', 'object': '[plan]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'had', 'object': '[plan]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'said', 'object': '[plan]', 'TalkID': 96},
#  {'subject': 'we', 'verb': 'had', 'object': '[fireworks]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'do', 'object': '[shit]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'stopped', 'object': '[shit]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'had', 'object': '[plan]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'know', 'object': '[plan]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'going', 'object': '[what, to, say]', 'TalkID': 96},
#  {'subject': 'people', 'verb': 'start', 'object': '[to, live]', 'TalkID': 96},
#  {'subject': 'they', 'verb': 'face', 'object': '[death]', 'TalkID': 96},
#  {'subject': 'you',
#   'verb': 'going',
#   'object': '[to, get, off, this, island, ,]',
#   'TalkID': 96},
#  {'subject': 'you', 'verb': 'going', 'object': '[to, die]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'call', 'object': '[who]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'say', 'object': '[what]', 'TalkID': 96},
#  {'subject': 'you', 'verb': 'do', 'object': '[what]', 'TalkID': 96},
#  {'subject': 'boyfriend',
#   'verb': 'wanted',
#   'object': '[to, marry, her]',
#   'TalkID': 96},
#  {'subject': 'she',
#   'verb': 'said',
#   'object': '[to, marry, her]',
#   'TalkID': 96},
#  {'subject': 'she', 'verb': 'called', 'object': '[him]', 'TalkID': 96},
#  {'subject': 'she', 'verb': 'left', 'object': '[message]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'love', 'object': '[you]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'want', 'object': '[to, marry, you]', 'TalkID': 96},
#  {'subject': 'he', 'verb': 'called', 'object': '[her]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'tell', 'object': '[you]', 'TalkID': 96},
#  {'subject': 'this', 'verb': 'means', 'object': '[what]', 'TalkID': 96},
#  {'subject': 'i',
#   'verb': 'know',
#   'object': '[how, to, tell, you, this]',
#   'TalkID': 96},
#  {'subject': 'you', 'verb': 'gave', 'object': '[gift]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'going', 'object': '[to, die]', 'TalkID': 96},
#  {'subject': 'she', 'verb': 'played', 'object': '[recording]', 'TalkID': 96},
#  {'subject': 'anything', 'verb': 'stop', 'object': '[you]', 'TalkID': 96},
#  {'subject': 'i',
#   'verb': 'love',
#   'object': "[to, hold, your, hand, and, say, i, 'm, sorry]",
#   'TalkID': 96},
#  {'subject': 'i', 'verb': 'tell', 'object': '[rest]', 'TalkID': 96},
#  {'subject': 'i',
#   'verb': 'want',
#   'object': '[to, be, respectful]',
#   'TalkID': 96},
#  {'subject': 'i', 'verb': 'tell', 'object': '[you]', 'TalkID': 96},
#  {'subject': 'i', 'verb': 'brought', 'object': '[man]', 'TalkID': 96},
#  ...]

# %%
svos_mbt = pd.DataFrame(svos_m_by_talk)
svos_wbt = pd.DataFrame(svos_w_by_talk)

# %%
svos_mbt
# Out:
#         subject     verb                                             object  \
# 0             i    blown                                       [conference]
# 1             i     want  [to, thank, all, of, you, for, the, many, nice...
# 2             i     need                                             [that]
# 3      laughter      put                                       [yourselves]
# 4             i     have  [to, take, off, my, shoes, or, boots, to, get,...
# ...         ...      ...                                                ...
# 80545       you  imagine                                              [him]
# 80546       you      see                                   [credit, rating]
# 80547        we       do                                             [what]
# 80548        it   expose                                         [humanity]
# 80549        it   reveal                                           [demons]
#
#        TalkID
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 80545   10807
# 80546   10807
# 80547   10807
# 80548   10807
# 80549   10807
#
# [80550 rows x 4 columns]

# %% [markdown]
# ### Post-SVO Lemmatizing
#
# Two possible approaches to lemmatizing verbs in a dataframe:
# * [How to lemmatise a dataframe column Python - Stack Overflow](https://stackoverflow.com/questions/61987040/how-to-lemmatise-a-dataframe-column-python)
# * [dataframe - lemmatizing a verb list in a data frame in Python - Stack Overflow](https://stackoverflow.com/questions/72394840/lemmatizing-a-verb-list-in-a-data-frame-in-python)

# %%
from nltk.stem import WordNetLemmatizer

# %%
# https://www.nltk.org/_modules/nltk/stem/wordnet.html
wnl = WordNetLemmatizer()
svos_wbt.verb.map(lambda word: wnl.lemmatize(word, pos="v"))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File /opt/anaconda3/envs/tedtalks/lib/python3.9/site-packages/nltk/corpus/util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File /opt/anaconda3/envs/tedtalks/lib/python3.9/site-packages/nltk/data.py:583, in find(resource_name, paths)
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource omw-1.4 not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('omw-1.4')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/omw-1.4.zip/omw-1.4/
#
#   Searched in:
#     - '/Users/katiek/nltk_data'
#     - '/opt/anaconda3/envs/tedtalks/nltk_data'
#     - '/opt/anaconda3/envs/tedtalks/share/nltk_data'
#     - '/opt/anaconda3/envs/tedtalks/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Input In [49], in <module>
#       1 # https://www.nltk.org/_modules/nltk/stem/wordnet.html
#       2 wnl = WordNetLemmatizer()
# ----> 3 svos_wbt.verb.map(lambda word: wnl.lemmatize(word, pos="v"))
#
# File /opt/anaconda3/envs/tedtalks/lib/python3.9/site-packages/pandas/core/series.py:4234, in Series.map(self, arg, na_action)
#    4159 def map(self, arg, na_action=None) -> Series:
#    4160     """
#    4161     Map values of Series according to an input mapping or function.
#    4162
#    (...)
#    4232     dtype: object
#    4233     """
# -> 4234     new_values = self._map_values(arg, na_action=na_action)
#    4235     return self._constructor(new_values, index=self.index).__finalize__(
#    4236         self, method="map"
#    4237     )
#
# File /opt/anaconda3/envs/tedtalks/lib/python3.9/site-packages/pandas/core/base.py:880, in IndexOpsMixin._map_values(self, mapper, na_action)
#     877         raise ValueError(msg)
#     879 # mapper is a function
# --> 880 new_values = map_f(values, mapper)
#     882 return new_values
#
# File /opt/anaconda3/envs/tedtalks/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Input In [49], in <lambda>(word)
#       1 # https://www.nltk.org/_modules/nltk/stem/wordnet.html
#       2 wnl = WordNetLemmatizer()
# ----> 3 svos_wbt.verb.map(lambda word: wnl.lemmatize(word, pos="v"))
#
# File /opt/anaconda3/envs/tedtalks/lib/python3.9/site-packages/nltk/stem/wordnet.py:45, in WordNetLemmatizer.lemmatize(self, word, pos)
#      33 def lemmatize(self, word: str, pos: str = "n") -> str:
#      34     """Lemmatize `word` using WordNet's built-in morphy function.
#      35     Returns the input word unchanged if it cannot be found in WordNet.
#      36
#    (...)
#      43     :return: The lemma of `word`, for the given `pos`.
#      44     """
# ---> 45     lemmas = wn._morphy(word, pos)
#      46     return min(lemmas, key=len) if lemmas else word
#
# File /opt/anaconda3/envs/tedtalks/lib/python3.9/site-packages/nltk/corpus/util.py:121, in LazyCorpusLoader.__getattr__(self, attr)
#     118 if attr == "__bases__":
#     119     raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
# --> 121 self.__load()
#     122 # This looks circular, but its not, since __load() changes our
#     123 # __class__ to something new:
#     124 return getattr(self, attr)
#
# File /opt/anaconda3/envs/tedtalks/lib/python3.9/site-packages/nltk/corpus/util.py:89, in LazyCorpusLoader.__load(self)
#      86             raise e
#      88 # Load the corpus.
# ---> 89 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#      91 # This is where the magic happens!  Transform ourselves into
#      92 # the corpus by modifying our own __dict__ and __class__ to
#      93 # match that of the corpus.
#      95 args, kwargs = self.__args, self.__kwargs
#
# File /opt/anaconda3/envs/tedtalks/lib/python3.9/site-packages/nltk/corpus/reader/wordnet.py:1176, in WordNetCorpusReader.__init__(self, root, omw_reader)
#    1172     warnings.warn(
#    1173         "The multilingual functions are not available with this Wordnet version"
#    1174     )
#    1175 else:
# -> 1176     self.provenances = self.omw_prov()
#    1178 # A cache to store the wordnet data of multiple languages
#    1179 self._lang_data = defaultdict(list)
#
# File /opt/anaconda3/envs/tedtalks/lib/python3.9/site-packages/nltk/corpus/reader/wordnet.py:1285, in WordNetCorpusReader.omw_prov(self)
#    1283 provdict = {}
#    1284 provdict["eng"] = ""
# -> 1285 fileids = self._omw_reader.fileids()
#    1286 for fileid in fileids:
#    1287     prov, langfile = os.path.split(fileid)
#
# File /opt/anaconda3/envs/tedtalks/lib/python3.9/site-packages/nltk/corpus/util.py:121, in LazyCorpusLoader.__getattr__(self, attr)
#     118 if attr == "__bases__":
#     119     raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
# --> 121 self.__load()
#     122 # This looks circular, but its not, since __load() changes our
#     123 # __class__ to something new:
#     124 return getattr(self, attr)
#
# File /opt/anaconda3/envs/tedtalks/lib/python3.9/site-packages/nltk/corpus/util.py:86, in LazyCorpusLoader.__load(self)
#      84             root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85         except LookupError:
# ---> 86             raise e
#      88 # Load the corpus.
#      89 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#
# File /opt/anaconda3/envs/tedtalks/lib/python3.9/site-packages/nltk/corpus/util.py:81, in LazyCorpusLoader.__load(self)
#      79 else:
#      80     try:
# ---> 81         root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82     except LookupError as e:
#      83         try:
#
# File /opt/anaconda3/envs/tedtalks/lib/python3.9/site-packages/nltk/data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource omw-1.4 not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('omw-1.4')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/omw-1.4
#
#   Searched in:
#     - '/Users/katiek/nltk_data'
#     - '/opt/anaconda3/envs/tedtalks/nltk_data'
#     - '/opt/anaconda3/envs/tedtalks/share/nltk_data'
#     - '/opt/anaconda3/envs/tedtalks/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %%
svos_wbt.shape
# Out:
# (26610, 3)

# %%
svos_mbt.verb = svos_m.verb.map(lambda word: wnl.lemmatize(word, pos="v"))

# %%
# Save to CSV files 
# >>> Commented out once run
svos_wbt.to_csv("../output/svos_wbt_lem.csv")
svos_mbt.to_csv("../output/svos_mbt_lem.csv")
