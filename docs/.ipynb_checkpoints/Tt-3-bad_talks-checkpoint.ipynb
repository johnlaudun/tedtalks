# %%
#! /usr/bin/env python

import pandas
import re
import csv

# Get all talks in a list & then into one string
colnames = ['author', 'title', 'date' , 'length', 'text']
df = pandas.read_csv('../data/talks-v1b.csv', names=colnames)
talks = df.text.tolist()
alltalks = " ".join(str(item) for item in talks) # Solves pbm of floats in talks
all_words = re.sub(r"[^\w\d'\s]+",'',alltalks).lower() # Remove all punctuation save apostrophes


# Tokenize on whitespace with NLTK
from nltk.tokenize import WhitespaceTokenizer
tt_tokens = WhitespaceTokenizer().tokenize(all_words)

# Build a dictionary of words and their frequency in the corpus
tt_freq = {}
for word in tt_tokens:
    try:
        tt_freq[word] += 1
    except: 
        tt_freq[word] = 1

# Convert dictionary into a list of tuples
tt_freq_list = [(val, key) for key, val in tt_freq.items()]

# Sort with most frequent words at top
tt_freq_list.sort(reverse=True)

# Write to file
with open('../outputs/tt_freq.csv', 'w') as f:
        wtr = csv.writer(f)
        wtr.writerows(sorted(tt_freq_list, reverse=True))
        f.close()

# %%
# Discovering the Bad Texts

# We establish which talks are empty
i = 0
no_good = []
for talk in talks:
    A = type(talk)
    B = type('string or something')
    if A != B:
        no_good.append(i)
    i = i + 1

print(no_good)
# Out:
# [185, 398, 513, 877, 1015, 1100, 2011]

# %%
df.iloc[no_good]
# Out:
#                            author  \
# 185               Quixotic Fusion
# 398              Bruno Maisonnier
# 513                 Kenichi Ebina
# 877                 Aakash Odedra
# 1015               Joey Alexander
# 1100                    Kaki King
# 2011  Robert Gupta + Joshua Roman
#
#                                                  title      date  length text
# 185                                 Dancing with light  Jun 2012     718  NaN
# 398                                Dance, tiny robots!  Feb 2013      74  NaN
# 513                                     My magic moves  Oct 2007     204  NaN
# 877    A dance in a hurricane of paper, wind and light  Dec 2014     573  NaN
# 1015   An 11-year-old prodigy performs old-school jazz  Jun 2015     372  NaN
# 1100  A musical escape into a world of light and color  Nov 2015     671  NaN
# 2011                On violin and cello, "Passacaglia"  May 2011     526  NaN

# %%
j = 0
too_short = []
for talk in talks: 
    if len(str(talk)) < 1000:
        too_short.append(j)
    j = j + 1

# %%
print(len(too_short), too_short)
# Out:
# 21 [115, 185, 331, 398, 513, 877, 982, 1015, 1100, 1299, 1342, 1427, 1641, 1846, 1852, 1937, 1947, 2011, 2028, 2080, 2102]

# %%
df.iloc[too_short]
# Out:
#                                                  author  \
# 115                                   Improv Everywhere
# 185                                     Quixotic Fusion
# 331                               Sleepy Man Banjo Boys
# 398                                    Bruno Maisonnier
# 513                                       Kenichi Ebina
# 877                                       Aakash Odedra
# 982                                       Bill T. Jones
# 1015                                     Joey Alexander
# 1100                                          Kaki King
# 1299                    Bruno Bowden + Rufus Cappadocia
# 1342                                   James Burchfield
# 1427  Gustavo Dudamel and the Teresa Carreño Youth ...
# 1641                                     Herbie Hancock
# 1846                  David Byrne, Ethel + Thomas Dolby
# 1852                                      Miwa Matreyek
# 1937                                           Ahn Trio
# 1947                                        Jill Sobule
# 2011                        Robert Gupta + Joshua Roman
# 2028                                       Onyx Ashanti
# 2080                                   Rachelle Garniez
# 2102                                  Natalie MacMaster
#
#                                                   title      date  length  \
# 115                     A TED speaker's worst nightmare  Mar 2012     209
# 185                                  Dancing with light  Jun 2012     718
# 331                         Teen wonders play bluegrass  Nov 2012      12
# 398                                 Dance, tiny robots!  Feb 2013      74
# 513                                      My magic moves  Oct 2007     204
# 877     A dance in a hurricane of paper, wind and light  Dec 2014     573
# 982   The dancer, the singer, the cellist ... and a ...  May 2015     379
# 1015    An 11-year-old prodigy performs old-school jazz  Jun 2015     372
# 1100   A musical escape into a world of light and color  Nov 2015     671
# 1299                        Blindfold origami and cello  Aug 2008     159
# 1342                       Playing invisible turntables  Oct 2008     274
# 1427                   El Sistema's top youth orchestra  Feb 2009      11
# 1641                                    An all-star set  Jan 2010    1483
# 1846        "(Nothing But) Flowers" with string quartet  Oct 2010     181
# 1852      Glorious visions in animation and performance  Oct 2010     651
# 1937              A modern take on piano, violin, cello  Feb 2011     297
# 1947  Global warming's theme song, "Manhattan in Jan...  Apr 2007     143
# 2011                 On violin and cello, "Passacaglia"  May 2011     526
# 2028                                   This is beatjazz  Jun 2011     369
# 2080                                   "La Vie en Rose"  Apr 2007     191
# 2102                  Cape Breton fiddling in reel time  May 2007     297
#
#                                                    text
# 115   Today I'm going to talk about unexpected disco...
# 185                                                 NaN
# 331   Tommy Mizzone  Tonight we're going to play you...
# 398                                                 NaN
# 513                                                 NaN
# 877                                                 NaN
# 982   Isadora Duncan    crazy  long legged woman fro...
# 1015                                                NaN
# 1100                                                NaN
# 1299  Hello everyone. And so the two of us are here ...
# 1342  Let's just get started here. Okay  just a mome...
# 1427  Chris Anderson  And now we go live to Caracas ...
# 1641  Herbie Hancock  Thank you. Marcus Miller.  App...
# 1846    Here we stand     Like an Adam and an Eve   ...
# 1852    You learned how to be a diver     Put on a m...
# 1937  Angella Ahn  Thank you. Thank you so much. We ...
# 1947  Okay.   Strolling along in Central Park     Ev...
# 2011                                                NaN
# 2028  Text  BeatJazz. BeatJazz is   . Live looping  ...
# 2080  Thomas Dolby  For pure pleasure please welcome...
# 2102    Like the heather     on the hillside     as ...

# %%
with open('../data/drop_talks.txt', 'w') as f:
    for item in too_short:  
        f.write("%s\n" % item)
