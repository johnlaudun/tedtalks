# %%
#! /usr/bin/env python

# =-=-=-=-=-=
# Consolidated imports for entire notebook
# =-=-=-=-=-=

import pandas
import re
from nltk.tokenize import WhitespaceTokenizer
from nltk.stem import *
from nltk.stem.porter import *
import numpy as np
import sklearn.feature_extraction.text as sk_text
from sklearn.decomposition import NMF


# =-=-=-=-=-=
# Read CSV into DataFrame and then create lists
# =-=-=-=-=-=

# Create pandas dataframe & lists
colnames = ['author', 'title', 'date' , 'length', 'text']
df = pandas.read_csv('../data/talks_2.csv', names=colnames)
talks = df.text.tolist()
authors = df.author.tolist()
dates = df.date.tolist()

# Get years from date list and combing with author list for labels
years = [re.sub('[A-Za-z ]', '', item) for item in dates]
authordate = [author+" "+year for author, year in zip(authors, years)]

# =-=-=-=-=-=
# Clean and Tokenize, then Drop Stopwords
# =-=-=-=-=-=

# Load tokenizer, stopwords, and stemmer
tokenizer = WhitespaceTokenizer()
stopwords = re.split('\s+', open('../data/tt_stop.txt', 'r').read().lower())
p_stemmer = PorterStemmer()

# Loop to tokenize, stop, and stem (if needed) texts.
texts = []
for i in talks:   
    # clean and tokenize document string
    raw = re.sub(r"[^\w\d'\s]+",'', i).lower()
    tokens = tokenizer.tokenize(raw)
    # remove stop words from tokens
    stopped_tokens = [i for i in tokens if not i in stopwords]
    # stem tokens
    stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]
    # add tokens to list
    texts.append(stemmed_tokens)

# =-=-=-=-=-=-=-=-=-=-=
# Re-Assemble Texts as Strings from Lists of Words
# =-=-=-=-=-=-=-=-=-=-= 

strungs = []
for text in texts:
    strung = ' '.join(text)
    strungs.append(strung)

# %%
# =-=-=-=-=-=
# Get NMF topics
# =-=-=-=-=-=


# All our variables are here to make it easier to make adjustments
data_set = strungs # or talks
n_samples = len(data_set)
n_features = 1000
n_topics = 35
n_top_words = 15
# tt_stopwords = open('../data/stopwords_tt.txt', 'r').read().splitlines()

# Get tf-idf features for NMF
vectorizer = sk_text.TfidfVectorizer(max_df = 0.90,
                                        min_df = 0.01,
                                        max_features = n_features)
tfidf = vectorizer.fit_transform(data_set)

# Fit the NMF model
nmf = NMF(n_components = n_topics,
          random_state = 1,
          alpha = 0.1,
          l1_ratio = 0.5).fit(tfidf)
print("Fitting the NMF model with {} topics for {} documents with {} features."
      .format(n_topics, n_samples, n_features))
# Out:
# Fitting the NMF model with 35 topics for 2092 documents with 1000 features.

# %%
# =-=-=-=-=-=
# Get NMF printing
# =-=-=-=-=-=

def print_top_words(model, feature_names, n_top_words):
    for topic_id, topic in enumerate(model.components_):
        print('\nTopic {}:'.format(int(topic_id)))
        print(''.join([feature_names[i] + ' ' + str(round(topic[i], 2))
              +', ' for i in topic.argsort()[:-n_top_words - 1:-1]]))

features = vectorizer.get_feature_names()
#print(features)

print("Topics in NMF model:")

# KK - I get an error here. My python does not recognize tfidf_vectorizer()
#tfidf_feature_names = nmf.get_feature_names()
# This works now. I added features above. Probably broken by me
# not seeing a name change. 
print_top_words(nmf, features, n_top_words) #n_top_words can be changed on the fly
# Out:
# Topics in NMF model:
#
# Topic 0:
# thing 1.16, think 0.98, realli 0.9, get 0.84, know 0.79, peopl 0.78, actual 0.77, look 0.7, see 0.65, make 0.63, kind 0.59, right 0.56, littl 0.53, lot 0.51, work 0.51,
#
# Topic 1:
# said 0.96, know 0.61, life 0.58, day 0.54, peopl 0.51, love 0.51, stori 0.51, say 0.46, man 0.43, live 0.38, feel 0.37, went 0.36, father 0.36, home 0.35, come 0.34,
#
# Topic 2:
# dollar 0.65, market 0.58, percent 0.56, compani 0.54, busi 0.51, money 0.48, energi 0.41, economi 0.41, product 0.4, invest 0.38, econom 0.37, cost 0.36, growth 0.36, peopl 0.36, billion 0.36,
#
# Topic 3:
# planet 0.99, univers 0.78, earth 0.76, star 0.74, galaxi 0.68, space 0.44, light 0.4, mar 0.4, sun 0.39, solar 0.37, energi 0.31, see 0.29, life 0.27, billion 0.27, dark 0.26,
#
# Topic 4:
# cancer 2.35, bodi 0.18, molecul 0.17, diseas 0.16, blood 0.14, drug 0.11, treatment 0.09, gene 0.07, treat 0.06, percent 0.06, grow 0.05, test 0.05, chemic 0.05, lab 0.05, field 0.05,
#
# Topic 5:
# brain 2.58, neuron 0.61, activ 0.22, memori 0.18, control 0.17, mind 0.17, human 0.17, behavior 0.16, signal 0.16, bodi 0.16, arm 0.15, region 0.14, studi 0.14, imag 0.14, see 0.13,
#
# Topic 6:
# build 1.62, architectur 0.73, space 0.57, materi 0.5, structur 0.41, project 0.4, hous 0.35, built 0.34, creat 0.22, wall 0.2, work 0.19, construct 0.19, natur 0.18, air 0.18, open 0.18,
#
# Topic 7:
# women 2.58, men 1.04, girl 0.52, woman 0.43, femal 0.29, sex 0.29, male 0.23, equal 0.21, violenc 0.15, boy 0.13, mother 0.1, daughter 0.1, talk 0.1, young 0.1, educ 0.09,
#
# Topic 8:
# robot 2.52, leg 0.17, move 0.13, video 0.09, control 0.09, see 0.08, anim 0.08, interact 0.07, bodi 0.06, human 0.06, machin 0.05, express 0.05, lab 0.05, task 0.05, movement 0.05,
#
# Topic 9:
# citi 2.6, urban 0.43, map 0.35, street 0.33, park 0.27, new 0.26, york 0.26, space 0.22, peopl 0.22, live 0.2, place 0.18, public 0.15, commun 0.14, citizen 0.12, site 0.11,
#
# Topic 10:
# design 2.83, product 0.27, work 0.16, object 0.15, beauti 0.11, art 0.09, print 0.08, materi 0.08, new 0.08, kind 0.07, made 0.07, hospit 0.07, industri 0.07, process 0.07, realli 0.07,
#
# Topic 11:
# art 1.14, paint 0.93, artist 0.91, imag 0.71, see 0.4, light 0.38, film 0.36, museum 0.35, creat 0.33, work 0.33, photograph 0.28, camera 0.27, color 0.27, visual 0.25, object 0.25,
#
# Topic 12:
# music 2.49, play 0.24, hear 0.22, song 0.21, piec 0.21, sound 0.16, perform 0.14, video 0.13, listen 0.09, audienc 0.08, danc 0.07, record 0.07, note 0.07, bird 0.06, express 0.06,
#
# Topic 13:
# countri 0.64, peopl 0.64, govern 0.59, polit 0.59, world 0.53, war 0.52, democraci 0.51, state 0.43, societi 0.38, nation 0.35, global 0.34, power 0.33, china 0.31, chang 0.29, conflict 0.28,
#
# Topic 14:
# cell 2.47, drug 0.29, diseas 0.24, bodi 0.23, organ 0.23, bone 0.21, anim 0.21, lab 0.17, engin 0.15, biolog 0.14, materi 0.14, grow 0.13, actual 0.13, molecul 0.12, blood 0.11,
#
# Topic 15:
# dna 1.28, gene 1.02, genom 0.85, genet 0.5, sequenc 0.46, bacteria 0.41, speci 0.35, molecul 0.23, code 0.22, biolog 0.2, human 0.19, evolut 0.13, diseas 0.12, cell 0.12, organ 0.1,
#
# Topic 16:
# ca 2.06, yeah 0.25, chri 0.15, mean 0.12, think 0.1, got 0.09, ted 0.07, peopl 0.06, report 0.04, sourc 0.04, ok 0.04, amaz 0.04, charg 0.03, say 0.03, work 0.03,
#
# Topic 17:
# data 2.59, inform 0.58, map 0.25, look 0.15, see 0.15, collect 0.14, web 0.14, visual 0.13, imag 0.13, pattern 0.09, text 0.09, number 0.09, decis 0.08, rate 0.08, show 0.07,
#
# Topic 18:
# plant 1.65, food 1.08, forest 0.57, tree 0.47, eat 0.45, speci 0.42, anim 0.3, farm 0.29, grow 0.28, natur 0.22, feed 0.21, land 0.18, produc 0.16, percent 0.15, carbon 0.14,
#
# Topic 19:
# car 2.23, drive 0.53, road 0.35, mile 0.31, park 0.14, hour 0.1, charg 0.1, oil 0.1, price 0.1, electr 0.1, race 0.1, light 0.09, share 0.08, polic 0.07, fuel 0.07,
#
# Topic 20:
# book 2.04, read 0.69, stori 0.52, page 0.39, publish 0.29, text 0.28, write 0.25, author 0.2, wrote 0.15, imag 0.14, print 0.14, translat 0.13, sort 0.13, religion 0.12, digit 0.1,
#
# Topic 21:
# game 2.19, video 0.56, play 0.29, interact 0.18, win 0.13, virtual 0.1, world 0.08, real 0.07, boy 0.07, physic 0.06, onlin 0.06, social 0.05, engag 0.05, girl 0.05, activ 0.04,
#
# Topic 22:
# patient 1.5, diseas 0.69, health 0.69, drug 0.62, doctor 0.59, medic 0.56, medicin 0.41, hospit 0.4, treatment 0.4, care 0.38, clinic 0.37, hiv 0.29, heart 0.27, trial 0.24, treat 0.23,
#
# Topic 23:
# play 2.2, song 0.38, note 0.2, seriou 0.13, love 0.12, kid 0.12, creativ 0.11, fun 0.1, danc 0.1, littl 0.08, feel 0.07, electr 0.06, mom 0.05, explor 0.05, record 0.04,
#
# Topic 24:
# sound 1.65, voic 1.07, listen 0.75, hear 0.51, song 0.25, babi 0.2, record 0.2, wave 0.19, color 0.12, speak 0.1, laughter 0.09, visual 0.08, bodi 0.08, breath 0.07, heard 0.07,
#
# Topic 25:
# children 1.94, child 0.89, babi 0.54, famili 0.51, parent 0.45, mother 0.31, vaccin 0.29, india 0.27, school 0.2, countri 0.19, boy 0.18, develop 0.11, learn 0.1, old 0.1, world 0.1,
#
# Topic 26:
# africa 1.92, african 1.03, aid 0.42, hiv 0.37, countri 0.36, south 0.25, leader 0.15, world 0.15, invest 0.11, develop 0.1, opportun 0.1, stori 0.09, tradit 0.09, poverti 0.08, bank 0.08,
#
# Topic 27:
# comput 1.86, machin 1.51, program 0.28, human 0.22, intellig 0.17, physic 0.16, softwar 0.15, system 0.15, code 0.14, learn 0.14, built 0.13, interact 0.12, mathemat 0.12, lab 0.1, object 0.1,
#
# Topic 28:
# school 1.34, kid 1.27, teacher 1.0, student 0.94, educ 0.8, teach 0.51, learn 0.42, class 0.34, girl 0.21, math 0.16, parent 0.16, need 0.15, high 0.13, program 0.11, skill 0.11,
#
# Topic 29:
# languag 1.62, english 1.0, word 0.9, translat 0.35, speak 0.26, write 0.17, chines 0.16, say 0.16, text 0.15, mathemat 0.15, learn 0.15, letter 0.12, mean 0.08, read 0.07, teach 0.07,
#
# Topic 30:
# technolog 1.65, phone 0.81, digit 0.67, devic 0.65, mobil 0.48, inform 0.44, world 0.28, tool 0.25, innov 0.22, human 0.2, commun 0.2, connect 0.18, system 0.18, develop 0.17, access 0.16,
#
# Topic 31:
# ocean 1.42, fish 1.0, sea 0.74, anim 0.63, speci 0.28, ice 0.23, island 0.22, deep 0.21, explor 0.19, protect 0.19, creatur 0.19, area 0.18, water 0.17, planet 0.17, surfac 0.16,
#
# Topic 32:
# fli 1.93, bird 0.21, camera 0.19, control 0.18, neuron 0.16, air 0.14, babi 0.13, jump 0.11, power 0.1, land 0.1, effici 0.1, engin 0.09, speed 0.09, space 0.09, solar 0.09,
#
# Topic 33:
# internet 1.2, media 0.61, web 0.61, onlin 0.55, video 0.46, network 0.45, page 0.37, govern 0.28, content 0.27, site 0.26, googl 0.25, compani 0.25, link 0.24, inform 0.24, social 0.23,
#
# Topic 34:
# water 2.4, river 0.33, energi 0.24, ice 0.21, wast 0.21, clean 0.17, bacteria 0.16, materi 0.15, surfac 0.13, oil 0.13, suppli 0.12, heat 0.11, air 0.11, fuel 0.1, system 0.09,

# %%
dtm = tfidf.toarray()
doctopic = nmf.fit_transform(dtm) # This is an array

dtm.shape

# %%
for topicidx in enumerate(nmf.components_):
    print(topicidx)

# %%
# =-=-=-=-=-=
# Saving output to CSV
# =-=-=-=-=-=

# Since DOCTOPIC is an array, you can just do:
#      np.savetxt("foo.csv", doctopic, delimiter=",", fmt = "%s")
# http://stackoverflow.com/questions/6081008/dump-a-numpy-array-into-a-csv-file
#
# The above won't give you the names of the files. Instead try this:

topsnum = np.array([list(range(n_topics))])
# topsnum = np.indices((1,n_topics))[1] <-- this is more than we need,
#                                           but it's cool to know more tricks
#
# Two ways to get an array that is of the form [[0,1,2,3,...]].
# It will have the desired dimensions of (1,35) which is what we want

fileheader = np.concatenate((np.array([["citations"]]), topsnum),axis = 1)
authordate = np.array([df.author])

docTopics = np.concatenate((authordate.T, doctopic), axis = 1)
docTopics = np.concatenate((fileheader, docTopics), axis = 0)

np.savetxt("../data/dt_KK_test.csv", doctopic, delimiter=",", fmt = "%s")
#np.savetxt("../data/nmf_topics.csv", docTopics, delimiter=",", fmt = "%s")
