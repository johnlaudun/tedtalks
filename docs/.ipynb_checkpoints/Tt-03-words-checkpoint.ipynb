# %%
#! /usr/bin/env python

import pandas
import re
from nltk.tokenize import WhitespaceTokenizer
from nltk.stem.snowball import SnowballStemmer
# from nltk.stem import *
# from nltk.stem.porter import *

# =-=-=-=-=-=
# Read CSV into DataFrame and then create lists
# =-=-=-=-=-=

# Create pandas dataframe
colnames = ['author', 'title', 'date' , 'length', 'text']
df = pandas.read_csv('../data/talks_2.csv', names=colnames)

# Create lists for the data
talks = df.text.tolist()
authors = df.author.tolist()
dates = df.date.tolist()

# Getting only the years from dates list
years = [re.sub('[A-Za-z ]', '', item) for item in dates]

# Combining year with presenter for citation
authordate = [author+" "+year for author, year in zip(authors, years)]

# Just to check to see if things are synced,
# let's create a new df with the two lists.

cited_texts = pandas.DataFrame(
    {'citation': authordate,
     'text': talks,
    })

# %%
# =-=-=-=-=-=
# Clean and Tokenize, then Drop Stopwords
# =-=-=-=-=-=

# Load tokenizer, stopwords, and stemmer
tokenizer = WhitespaceTokenizer()
stopwords = re.split('\s+', open('../data/tt_stop.txt', 'r').read().lower())
stemmer = SnowballStemmer("english", ignore_stopwords=True)
p_stemmer = PorterStemmer()

# List for loop
texts = []

# loop through document list
for i in talks:
    
    # clean and tokenize document string
    raw = re.sub(r"[^\w\d'\s]+",'', i).lower()
    tokens = tokenizer.tokenize(raw)

    # remove stop words from tokens
    stopped_tokens = [i for i in tokens if not i in stopwords]
    
    # stem tokens
    stemmed_tokens = [stemmer.stem(i) for i in stopped_tokens]
    
    # add tokens to list
#    texts.append(tokens)
    texts.append(stemmed_tokens)

print(texts[0:5])
# Out:
# [['thank', 'chris', 'truli', 'great', 'honor', 'opportun', 'come', 'stage', 'twice', 'extrem', 'grate', 'blown', 'away', 'confer', 'thank', 'nice', 'comment', 'say', 'night', 'say', 'sincer', 'part', 'mock', 'sob', 'need', 'put', 'posit', 'flew', 'air', 'forc', 'two', 'eight', 'year', 'take', 'shoe', 'boot', 'get', 'airplan', 'tell', 'quick', 'stori', 'illustr', 'like', 'true', 'stori', 'bit', 'true', 'soon', 'tipper', 'left', 'mock', 'sob', 'white', 'hous', 'drive', 'home', 'nashvill', 'littl', 'farm', 'mile', 'east', 'nashvill', 'drive', 'know', 'sound', 'like', 'littl', 'thing', 'look', 'rear', 'view', 'mirror', 'sudden', 'just', 'hit', 'motorcad', 'back', 'heard', 'phantom', 'limb', 'pain', 'rent', 'ford', 'taurus', 'dinnertim', 'start', 'look', 'place', 'eat', 'got', 'exit', 'lebanon', 'tennesse', 'got', 'exit', 'found', 'shoney', 'restaur', 'low', 'cost', 'famili', 'restaur', 'chain', 'know', 'went', 'sat', 'booth', 'waitress', 'came', 'made', 'big', 'commot', 'tipper', 'order', 'went', 'coupl', 'booth', 'lower', 'voic', 'realli', 'strain', 'hear', 'say', 'said', 'vice', 'presid', 'al', 'gore', 'wife', 'tipper', 'man', 'said', 'come', 'long', 'kind', 'seri', 'epiphani', 'day', 'continu', 'total', 'true', 'stori', 'got', 'g', 'v', 'fli', 'africa', 'make', 'speech', 'nigeria', 'citi', 'lago', 'topic', 'energi', 'speech', 'tell', 'stori', 'just', 'happen', 'day', 'nashvill', 'told', 'pretti', 'just', 'share', 'tipper', 'drive', 'shoney', 'low', 'cost', 'famili', 'restaur', 'chain', 'man', 'said', 'laugh', 'gave', 'speech', 'went', 'back', 'airport', 'fli', 'back', 'home', 'fell', 'asleep', 'plane', 'middl', 'night', 'land', 'azor', 'island', 'refuel', 'woke', 'open', 'door', 'went', 'get', 'fresh', 'air', 'look', 'man', 'run', 'runway', 'wave', 'piec', 'paper', 'yell', 'call', 'washington', 'call', 'washington', 'thought', 'middl', 'night', 'middl', 'atlant', 'world', 'wrong', 'washington', 'rememb', 'bunch', 'thing', 'turn', 'staff', 'extrem', 'upset', 'wire', 'servic', 'nigeria', 'written', 'stori', 'speech', 'print', 'citi', 'unit', 'state', 'america', 'print', 'monterey', 'check', 'stori', 'vice', 'presid', 'al', 'gore', 'announc', 'nigeria', 'yesterday', 'quot', 'my', 'wife', 'tipper', 'open', 'low', 'cost', 'famili', 'restaur', 'name', 'shoney', 'run', 'ourselv', 'get', 'back', 'soil', 'david', 'letterman', 'jay', 'leno', 'start', 'big', 'white', 'chef', 'hat', 'tipper', 'say', 'burger', 'fri', 'three', 'day', 'got', 'nice', 'long', 'handwritten', 'letter', 'friend', 'partner', 'colleagu', 'bill', 'clinton', 'say', 'congratul', 'new', 'restaur', 'al', 'like', 'celebr', 'other', 'success', 'life', 'go', 'talk', 'inform', 'ecolog', 'think', 'plan', 'make', 'lifelong', 'habit', 'come', 'back', 'ted', 'talk', 'time', 'chris', 'anderson', 'deal', 'al', 'gore', 'focus', 'said', 'like', 'elabor', 'climat', 'crisi', 'start', 'coupl', 'go', 'show', 'new', 'imag', 'go', 'recapitul', 'just', 'four', 'five', 'slide', 'show', 'updat', 'slide', 'show', 'time', 'give', 'add', 'new', 'imag', 'learn', 'time', 'give', 'like', 'beach', 'comb', 'know', 'time', 'tide', 'come', 'shell', 'just', 'last', 'two', 'day', 'got', 'new', 'temperatur', 'record', 'januari', 'just', 'unit', 'state', 'america', 'histor', 'averag', 'januari', 'degre', 'last', 'month', 'degre', 'know', 'want', 'bad', 'news', 'environ', 'kid', 'recapitul', 'slide', 'go', 'go', 'new', 'materi', 'want', 'elabor', 'coupl', 'first', 'project', 'go', 'contribut', 'global', 'warm', 'busi', 'usual', 'effici', 'end', 'electr', 'end', 'energi', 'low', 'hang', 'fruit', 'effici', 'conserv', 'cost', 'profit', 'sign', 'wrong', 'negat', 'posit', 'invest', 'pay', 'effect', 'deflect', 'path', 'car', 'truck', 'talk', 'slideshow', 'put', 'perspect', 'easi', 'visibl', 'target', 'concern', 'global', 'warm', 'pollut', 'come', 'build', 'car', 'truck', 'car', 'truck', 'signific', 'lowest', 'standard', 'world', 'address', 'puzzl', 'transport', 'effici', 'import', 'car', 'truck', 'renew', 'curre ...

# %%
plurals = ['caresses', 'flies', 'dies', 'mules', 'denied', 'died', 
           'agreed', 'owned', 'humbled', 'sized', 'meeting', 'stating', 
           'siezing', 'itemization', 'sensational', 'traditional', 
           'reference', 'colonizer', 'plotted']

singles = [stemmer.stem(plural) for plural in plurals]
print(' '.join(singles))
# Out:
# caress fli die mule deni die agre own humbl size meet state siez item sensat tradit refer colon plot
