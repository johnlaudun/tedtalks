# %%
import pandas as pd
import csv
import string
import numpy as np

# %%
talks = pd.read_csv('../../tedtalks/data/speakers_work/TEDplus_speakers_final.csv',sep = ',', encoding='utf-8')

# %%
talks.shape
# Out:
# (755, 27)

# %%
cols = list(talks.columns.values)
cols.pop(0)
print(cols)
print(talks.columns.values)
# Out:
# ['Talk_ID', 'public_url', 'headline', 'description', 'event', 'duration', 'published', 'tags', 'views', 'text', 'speaker_1', 'speaker1_occupation', 'speaker1_introduction', 'speaker1_profile', 'speaker_2', 'speaker2_occupation', 'speaker2_introduction', 'speaker2_profile', 'speaker_3', 'speaker3_occupation', 'speaker3_introduction', 'speaker3_profile', 'speaker_4', 'speaker4_occupation', 'speaker4_introduction', 'speaker4_profile']
# ['Unnamed: 0' 'Talk_ID' 'public_url' 'headline' 'description' 'event'
#  'duration' 'published' 'tags' 'views' 'text' 'speaker_1'
#  'speaker1_occupation' 'speaker1_introduction' 'speaker1_profile'
#  'speaker_2' 'speaker2_occupation' 'speaker2_introduction'
#  'speaker2_profile' 'speaker_3' 'speaker3_occupation'
#  'speaker3_introduction' 'speaker3_profile' 'speaker_4'
#  'speaker4_occupation' 'speaker4_introduction' 'speaker4_profile']

# %%
result1 = talks[cols]
result1.head()
# Out:
#    Talk_ID                                         public_url  \
# 0       37  https://www.ted.com/talks/jimmy_wales_on_the_b...
# 1       47  https://www.ted.com/talks/david_deutsch_on_our...
# 2       98  https://www.ted.com/talks/richard_dawkins_on_o...
# 3       93  https://www.ted.com/talks/barry_schwartz_on_th...
# 4       39  https://www.ted.com/talks/aubrey_de_grey_says_...
#
#                                       headline  \
# 0                       The birth of Wikipedia
# 1  Chemical scum that dream of distant quasars
# 2            Why the universe seems so strange
# 3                        The paradox of choice
# 4                       A roadmap to end aging
#
#                                          description           event duration  \
# 0  Jimmy Wales recalls how he assembled "a ragtag...  TEDGlobal 2005  0:20:01
# 1  Legendary scientist David Deutsch puts theoret...  TEDGlobal 2005  0:19:00
# ...

# %%
result1.to_csv('../../tedtalks/data/speakers_work/TEDplus_speakers_final.csv', sep = ',')
