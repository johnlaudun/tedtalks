# %% [markdown]
# # SVO Contexts
#
# This notebook allows us to examine the contexts in which words occur in sentences through the already-generated SVOs. We can quickly glimpse the related subjects, verbs, and objects for a particular word, though it has to be appear somewhere as an S, V, or O. For use of NLTK's `concordance` function, see the other contexts notebook.

# %%
# IMPORTS
import pandas as pd

# LOAD DATAFRAMES
# the `lem` suffix indicates the verbs have been lemmatized
df_load = pd.read_csv("../output/contexts-upto2svos.csv", low_memory=False)

# %%
# Get a list of all the columns
columns = df_load.columns.tolist()
print(columns)
# Out:
# ['Unnamed: 0', 'Talk_ID', 'public_url', 'headline', 'description', 'event', 'duration', 'published', 'tags', 'views', 'text', 'speaker_1', 'speaker_2', 'speaker_3', 'speaker_4', 'talk_gender', 'sentence', 'sentence_id', 's1', 'v1', 'o1', 's2', 'v2', 'o2']

# %%
# Drop columns for the sake of visual clarity
drop = ['Talk_ID', 'public_url', 'duration', 'published', 'text',
        'description', 'tags', 'speaker_2', 'speaker_3', 'speaker_4']
df = df_load.drop(columns=drop)

# %%
# Establish query pattern
df.query('(s1=="he" or s2=="he") & (v1=="kill" or v2=="kill")')
# Out:
#         Unnamed: 0                                     headline    event
# 25953        25953  The transformative power of classical music  TED2008  \
# 59422        59422                     How I became 100 artists  TED2011
# 59424        59424                     How I became 100 artists  TED2011
# 67718        67718      My invention that made peace with lions  TED2013
# 68555        68555       In search of the man who broke my neck  TED2013
# 101472      101472                        The illustrated woman  TED2007
# 102679      102679          My wish: The Charter for Compassion  TED2008
# 104031      104031              Once upon a time, my mother ...  TED2005
#
#           views          speaker_1 talk_gender
# 25953   9968703    Benjamin Zander        male  \
# 59422   1525148       Shea Hembrey        male
# 59424   1525148       Shea Hembrey        male
# 67718   2174131     Richard Turere        male
# 68555   1405153      Joshua Prager        male
# 101472   702690       Maira Kalman      female
# 102679  1433701    Karen Armstrong      female
# 104031   739635  Carmen Agra Deedy      female
#
#                                                  sentence sentence_id  s1
# 25953   That's in order to delay — until Act Five, he ...     286-130  he  \
# 59422   But when I was little, I remember, he would ki...     1169-10  he
# 59424   And what was amazing to me — well it was prett...     1169-12  he
# 67718    (Laughter) So he jumps in and kills the animals.     1699-23  he
# 68555   I told him only that he had killed one man, no...    1715-158   I
# 101472  And so, this is a chart of, you know, just a s...     182-135  he
# 102679  He kills Hector, he mutilates his body and the...     234-115  He
# 104031  And so we left my father fast asleep, because ...     347-122  we
#
#            v1       o1   s2        v2       o2
# 25953    kill      him  NaN       NaN      NaN
# 59422    kill    flies  NaN       NaN      NaN
# 59424    kill      fly  NaN       NaN      NaN
# 67718    jump  animals   he      kill  animals
# 68555    tell      him   he      kill      man
# 101472   kill     that  NaN       NaN      NaN
# 102679   kill   Hector   he  mutilate     body
# 104031  leave   father   he      kill       me

# %%
# Build that query pattern into a function
def contexts (subject, verb):
    pp= subject
    vb= verb
    women = df.query(
        '(s1==@pp or s2==@pp) & (v1==@vb or v2==@vb) & talk_gender=="female"'
        )['sentence']
    men = df.query(
        '(s1==@pp or s2==@pp) & (v1==@vb or v2==@vb) & talk_gender=="male"'
        )['sentence']
    for i in women:
        print(f"F: {i}\n")
    for i in men:
        print(f"M: {i}\n")

# %%
contexts("I", "stop")
# Out:
# F: I can never stop thinking about him or her."
#
# F: So for example, if I put out extra food, everybody else — the midden workers stop doing midden work and go get the food, they become foragers.
#
# F: So I'm like, "OK, I can't stop the stroke from happening, so I'll do this for a week or two, and then I'll get back to my routine.
#
# F: "Baby," I'll tell her, "remember, your momma is a worrier, and your poppa is a warrior, and you are the girl with small hands and big eyes who never stops asking for more."
#
# F: It was in a big pavilion in Greenville, an indoor pavilion, and I went to it because I was so frustrated as Governor that I couldn't stop the outflow of these jobs, and I wanted to grieve with them, and as I went into the room— there's thousands of people there.
#
# F: This is a slide to remind me that I should stop talking and get off of the stage.
#
# F: So in the first 18 months, I watched the police stop  pedestrians or people in cars, search people, run people's names, chase people through the streets, pull people in for questioning, or make an arrest every single day, with five exceptions.
#
# F: I stopped loving work.
#
# F: I play and I play until I begin to wonder why we ever stop playing in the first place.
#
# F: And she was obsessed with the exact moment when I would stop being able to tell the difference between her body and mine.
#
# F: And I stopped lifting weights.
#
# F: "Senior moment" quips, for example: I stopped making them when it dawned on me that when I lost the car keys in high school, I didn't call it a "junior moment."
#
# F: (Laughter)    I stopped blaming my sore knee on being 64.
#
# F: CS: I can't stop imagining what that might be.
#
# M: The second thing was, I stopped taking a salary from the church that I pastor.
#
# M: Here is an outside water fountain that I created with some friends of mine, but you can stop the water in drops and — actually make all the drops levitate.
#
# M: The years — and until I stopped looking at the polls, you were sort of regarded as this great hero in the U.K. and elsewhere.
#
# M: I stopped doing surgery about six years ago and became a full-time writer, as many people know.
#
# M: But I have to tell you — this is a guy doing stuff on a Quadra 950 computer — the resolution's a little bit low — using Infinity software they stopped making 15 years ago.
#
# M: I actually chased the mycelium, when it stopped producing spores.
#
# M: Anything I don't understand, where I have to make the leap myself, in my own head, will stop the flow of the presentation.
#
# M: I had stopped hearing the sound of the ocean.
#
# M: (Singing)    I'll stop it there in the interest of time.
#
# M: Well, I should tell you now what happened one night when all of the sensors stopped working.
#
# M: And I thought it would be incredible if in the middle of the wire I stopped and, like a magician, I produce a dove and send her in the sky as a living symbol of peace.
#
# M: I'll stop talking.
#
# M: So I then began looking at all the research plots I could over the whole of the Western United States where cattle had been removed to prove that it would stop desertification, but I found the opposite, as we see on this research station, where this grassland that was green in 1961, by 2002 had changed to that situation.
#
# M: I would have stopped to help."
#
# M: The school stopped in third grade, so then I entered the public school system, and it felt like I had been sent to the Gulag.
#
# M: I stopped them, those people.
#
# M: I can't stop shaking.
#
# M: And once I stopped complaining about how unfair it was that Jesus would return as soon as I had to be accountable for all that I had done, I figured I had better get my house in order very quickly.
#
# M: But there on that night, I did not stop believing.
#
# M: So if I lose connectivity, you would stop seeing beautiful things on the screen.
#
# M: And so I stopped using my voice in my work.
#
# M: So as I learned about the true nature of poverty, I couldn't stop wondering: Is this the idea we've all been waiting for?
#
# M: But then I stopped them.
