# %% [markdown]
# In this notebook, we examined the various kinds of TED events in order to determine which ones we wanted to keep and which ones were best removed from our research.

# %%
import pandas as pd

# %%
df = pd.read_csv('tedtalks2018.csv')
df.head()
# Out:
#    rowID  Talk_ID                                         public_url  \
# 0      0        1  https://www.ted.com/talks/al_gore_on_averting_...
# 1      1        7  https://www.ted.com/talks/david_pogue_says_sim...
# 2      2       53  https://www.ted.com/talks/majora_carter_s_tale...
# 3      3       66  https://www.ted.com/talks/ken_robinson_says_sc...
# 4      4       92  https://www.ted.com/talks/hans_rosling_shows_t...
#
#     speaker_name                         headline  \
# 0        Al Gore      Averting the climate crisis
# 1    David Pogue                 Simplicity sells
# 2  Majora Carter              Greening the ghetto
# 3   Ken Robinson      Do schools kill creativity?
# 4   Hans Rosling  The best stats you've ever seen
#
#                                          description    event duration  \
# 0  With the same humor and humanity he exuded in ...  TED2006  0:16:17
# 1  New York Times columnist David Pogue takes aim...  TED2006  0:21:26
# 2  In an emotionally charged talk, MacArthur-winn...  TED2006  0:18:36
# 3  Sir Ken Robinson makes an entertaining and pro...  TED2006  0:19:24
# 4  You've never seen data presented like this. Wi...  TED2006  0:19:50
#
#   published                                               tags     views  \
# 0   6/27/06  alternative energy,cars,global issues,climate ...   3266733
# 1   6/27/06  simplicity,entertainment,interface design,soft...   1702201
# 2   6/27/06  MacArthur grant,cities,green,activism,politics...   2000421
# 3   6/27/06  children,teaching,creativity,parenting,culture...  51614087
# 4   6/27/06  demo,Asia,global issues,visualizations,global ...  12662135
#
#                                                 text
# 0    Thank you so much, Chris. And it's truly a g...
# 1    (Music: "The Sound of Silence," Simon & Garf...
# 2    If you're here today — and I'm very happy th...
# 3    Good morning. How are you?    (Laughter)    ...
# 4    About 10 years ago, I took on the task to te...

# %%
data2 = df[~df['event'].str.contains('TEDx')].copy()

# Code from SEE LINK IN HANGOUTS

# %%
events = data2.event.unique()
print(events)
# Out:
# ['TED2006' 'TED2004' 'TED2005' 'TEDGlobal 2005' 'TEDSalon 2006' 'TED2003'
#  'TED2007' 'TED2002' 'TEDGlobal 2007' 'TEDSalon 2007 Hot Science'
#  'Skoll World Forum 2007' 'TED2008' 'TED1984' 'TED1990' 'DLD 2007'
#  'EG 2007' 'TED1998' 'LIFT 2007' 'TED Prize Wish' 'Chautauqua Institution'
#  'TEDSalon 2009 Compassion' 'Serious Play 2008' 'Taste3 2008' 'TED2001'
#  'TED in the Field' 'TED2009' 'EG 2008' 'Elizabeth G. Anderson School'
#  'TED@State' 'TEDGlobal 2009' 'TEDIndia 2009' 'TEDSalon London 2009'
#  'TEDMED 2009' 'TED2010' 'Arbejdsglaede Live' 'Mission Blue Voyage'
#  'TEDSalon London 2010' 'TED@Cannes' 'TEDGlobal 2010'
#  'Business Innovation Factory' 'TED Senior Fellows at TEDGlobal 2010'
#  'TEDWomen 2010' 'TEDSalon NY2011' 'TEDMED 2010' 'TED@MotorCity'
#  'TEDPrize@UN' 'TED2011' 'TEDActive 2011' 'INK Conference'
#  'Full Spectrum Auditions' 'TEDSalon London Spring 2011' 'TEDGlobal 2011'
#  'TEDMED 2011' 'TEDSalon NY2012' 'TED1994' 'TEDSalon London Fall 2011'
#  'TEDYouth 2011' 'TED2012' 'TED-Ed' 'TED@SXSWi' 'TEDMED 2012'
#  'TEDSalon London Spring 2012' 'TEDGlobal 2012' 'TED@London'
#  'TED@Bangalore' 'TED@New York' 'TED@Nairobi' 'TED@Johannesburg'
#  'TEDSalon London Fall 2012' 'TEDSalon NY2013' 'TED2013' 'TEDYouth 2012'
#  'TED@Intel' 'TED Talks Education' 'TEDMED 2013' 'TEDGlobal 2013'
#  'TEDCity2.0' 'TED@BCG Singapore' 'TED@NYC' 'TEDWomen 2013'
#  'TEDYouth 2013' 'TED@BCG San Francisco' 'TED@State Street Boston'
#  'TED Fellows Retreat 2013' 'TED2014' 'TEDActive 2014' 'TEDSalon NY2014'
#  'TEDSalon Berlin 2014' 'TED@Unilever' 'TEDMED 2014' 'TEDGlobal 2014'
#  'TED@IBM' 'TED@BCG Berlin' 'TEDYouth 2014' 'TED@State Street London'
#  'TED2015' 'TEDWomen 2015' 'TEDSalon NY2015' 'TEDGlobalLondon'
#  'TED@BCG London' 'TEDGlobal>London' 'TED Fellows Retreat 2015'
#  'TED Fellows 2015' 'Mission Blue II' 'TED@UPS' 'TEDYouth 2015'
#  'TEDGlobal>Geneva' 'TEDMED 2015' 'TED2016' 'TED Talks Live'
#  'Global Witness HQ' 'TEDActive 2015' 'TED Studio' 'TED@BCG Paris'
#  'TEDSummit' 'TEDNYC' 'TEDWomen 2016' 'TED Residency' 'TEDMED 2016'
#  'TED Dialogues' 'TED-Ed Weekend' 'TEDLagos Ideas Search' 'TED2017'
#  'TEDNairobi Ideas Search' 'TEDGlobal 2017' 'TEDGlobal>NYC'
#  'TED@BCG Milan' 'TEDWomen 2017' 'TED@Tommy'
#  'TED@Merck KGaA, Darmstadt, Germany' 'TED@Westpac' 'TEDMED 2017'
#  'A TED Original Podcast' 'Small Thing Big Idea']

# %%
# Checked the following events

data2[data2['event'].str.contains('TED1984')] # 1 talk: Negroponte

data2[data2['event'].str.contains('TED1990')] # 3 talks

data2[data2['event'].str.contains('TED1998')] # 6 talks

data2[data2['event'].str.contains('TEDSalon 2006')]

data2[data2['event'].str.contains('TEDSalon London Spring 2011')]

data2[data2['event'].str.contains('TED@Johannesburg')]

data2[data2['event'].str.contains('TED@UPS')]

data2[data2['event'].str.contains('TED Fellows Retreat 2013')]

data2[data2['event'].str.contains('Business Innovation Factory')]

data2[data2['event'].str.contains('TED@IBM')]

# %% [markdown]
# Ultimately, we decided to split the corpus into three groups:
#
# 1. the main TED conferences, e.g. "TED 2006"
# 2. the associated TED full conferences as listed on the Wikipedia page (https://en.wikipedia.org/wiki/TED_(conference)): TEDMED, TEDSummit, TEDWomen, TEDActive, TEDYouth, TEDGlobal, TED Talks Live.
# 3. the TEDx talks

# %%
TEDs = df[df['event'].str.contains('TED[0-9]{4}')].copy()
TEDs.shape
# Out:
# (992, 12)

# %%
TEDs.head()
# Out:
#    rowID  Talk_ID                                         public_url  \
# 0      0        1  https://www.ted.com/talks/al_gore_on_averting_...
# 1      1        7  https://www.ted.com/talks/david_pogue_says_sim...
# 2      2       53  https://www.ted.com/talks/majora_carter_s_tale...
# 3      3       66  https://www.ted.com/talks/ken_robinson_says_sc...
# 4      4       92  https://www.ted.com/talks/hans_rosling_shows_t...
#
#     speaker_name                         headline  \
# 0        Al Gore      Averting the climate crisis
# 1    David Pogue                 Simplicity sells
# 2  Majora Carter              Greening the ghetto
# 3   Ken Robinson      Do schools kill creativity?
# 4   Hans Rosling  The best stats you've ever seen
#
#                                          description    event duration  \
# 0  With the same humor and humanity he exuded in ...  TED2006  0:16:17
# 1  New York Times columnist David Pogue takes aim...  TED2006  0:21:26
# 2  In an emotionally charged talk, MacArthur-winn...  TED2006  0:18:36
# 3  Sir Ken Robinson makes an entertaining and pro...  TED2006  0:19:24
# 4  You've never seen data presented like this. Wi...  TED2006  0:19:50
#
#   published                                               tags     views  \
# 0   6/27/06  alternative energy,cars,global issues,climate ...   3266733
# 1   6/27/06  simplicity,entertainment,interface design,soft...   1702201
# 2   6/27/06  MacArthur grant,cities,green,activism,politics...   2000421
# 3   6/27/06  children,teaching,creativity,parenting,culture...  51614087
# 4   6/27/06  demo,Asia,global issues,visualizations,global ...  12662135
#
#                                                 text
# 0    Thank you so much, Chris. And it's truly a g...
# 1    (Music: "The Sound of Silence," Simon & Garf...
# 2    If you're here today — and I'm very happy th...
# 3    Good morning. How are you?    (Laughter)    ...
# 4    About 10 years ago, I took on the task to te...

# %%
# TEDs.to_csv('TEDonly.csv')

# %%
TEDevents = TEDs.event.unique().tolist()

# %%
TEDevents.sort()
print(TEDevents)
# Out:
# ['TED1984', 'TED1990', 'TED1994', 'TED1998', 'TED2001', 'TED2002', 'TED2003', 'TED2004', 'TED2005', 'TED2006', 'TED2007', 'TED2008', 'TED2009', 'TED2010', 'TED2011', 'TED2012', 'TED2013', 'TED2014', 'TED2015', 'TED2016', 'TED2017']

# %%
other_teds = ["TEDMED", "TEDSummit", "TEDWomen", "TEDActive", "TEDYouth", "TEDGlobal"]
search pattern = other_teds + " " + [0-9]{4}
